# %% [markdown]
# ## ISI Epilepsy Exploratory Data Analysis (EDA) with H2o AutoML (Brno)
#
# <u>**Goal:**</u> Conduct an exploratory data analysis with the prediction of pathology
#
# 20/7/2022

# %% [markdown]
# ---

# %%
# Import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Import dataset

epilepsy = pd.read_csv('/Users/marek/Desktop/Marek/Jobs/ISI/Work/data/isi_data.csv')
# Remove unnamed column: ,index_col=0
epilepsy.head()
# Out:
#    Unnamed: 0  patient_id channel_name  resected  structure onset_channel  \
# 0           0         583          ra1         0        NaN       NON_SOZ
# 1           1         583          ra2         0        NaN       NON_SOZ
# 2           2         583          ra3         0        NaN       NON_SOZ
# 3           3         583          ra4         0        NaN       NON_SOZ
# 4           4         583          ra5         0        NaN       NON_SOZ
#
#   pathology  outcome  HFO_65.0-80.0  HFO_80.0-250.0  ...  \
# 0    normal     11.0              0              11  ...
# 1    normal     11.0              0              16  ...
# 2    normal     11.0              0              20  ...
# 3    normal     11.0              0              27  ...
# 4    normal     11.0              0              11  ...
#
#    coherence_80.0-250.0  lin_corr_median_250.0-600.0  ren_250.0-600.0  \
# 0              0.997413                     0.990955         0.004121
# 1              0.998458                     0.993981         0.002847
# 2              0.999506                     0.996993         0.001647
# 3              0.999126                     0.995900         0.002311
# 4              0.997734                     0.995822         0.002367
#
#    phase_sync_250.0-600.0  phase_const_250.0-600.0  pli_250.0-600.0  \
# 0                0.970733                      1.0         0.815222
# 1                0.979349                      1.0         0.841924
# 2                0.987957                      1.0         0.857311
# 3                0.986385                      1.0         0.852814
# 4                0.986189                      1.0         0.861413
#
#    pli_tau_250.0-600.0  coherence_250.0-600.0  segm_type  segm_number
# 0            -0.146667               0.994151          0            0
# 1            -0.113333               0.996071          0            0
# 2            -0.043333               0.997980          0            0
# 3            -0.036667               0.997646          0            0
# 4            -0.058333               0.997589          0            0
#
# [5 rows x 98 columns]

# %%
# Plotting setup

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [14, 7]
plt.rcParams['figure.dpi'] = 160

# %%
# Show null columns

sns.heatmap(epilepsy.isnull(), cmap = 'viridis', cbar = True);

#pd.options.display.min_rows = 30
#epilepsy.isnull().sum()

# %%
# Drop index column

epilepsy = epilepsy.loc[:, ~epilepsy.columns.str.contains('^Unnamed')]
epilepsy.head()
# Out:
#    patient_id channel_name  resected  structure onset_channel pathology  \
# 0         583          ra1         0        NaN       NON_SOZ    normal
# 1         583          ra2         0        NaN       NON_SOZ    normal
# 2         583          ra3         0        NaN       NON_SOZ    normal
# 3         583          ra4         0        NaN       NON_SOZ    normal
# 4         583          ra5         0        NaN       NON_SOZ    normal
#
#    outcome  HFO_65.0-80.0  HFO_80.0-250.0  HFO_250.0-600.0  ...  \
# 0     11.0              0              11               34  ...
# 1     11.0              0              16               40  ...
# 2     11.0              0              20               35  ...
# 3     11.0              0              27               37  ...
# 4     11.0              0              11               58  ...
#
#    coherence_80.0-250.0  lin_corr_median_250.0-600.0  ren_250.0-600.0  \
# 0              0.997413                     0.990955         0.004121
# 1              0.998458                     0.993981         0.002847
# 2              0.999506                     0.996993         0.001647
# 3              0.999126                     0.995900         0.002311
# 4              0.997734                     0.995822         0.002367
#
#    phase_sync_250.0-600.0  phase_const_250.0-600.0  pli_250.0-600.0  \
# 0                0.970733                      1.0         0.815222
# 1                0.979349                      1.0         0.841924
# 2                0.987957                      1.0         0.857311
# 3                0.986385                      1.0         0.852814
# 4                0.986189                      1.0         0.861413
#
#    pli_tau_250.0-600.0  coherence_250.0-600.0  segm_type  segm_number
# 0            -0.146667               0.994151          0            0
# 1            -0.113333               0.996071          0            0
# 2            -0.043333               0.997980          0            0
# 3            -0.036667               0.997646          0            0
# 4            -0.058333               0.997589          0            0
#
# [5 rows x 97 columns]

# %%
# Remove unnecessary columns

epilepsy = epilepsy.drop(['structure'], axis=1)
epilepsy.head()
# Out:
#    patient_id channel_name  resected onset_channel pathology  outcome  \
# 0         583          ra1         0       NON_SOZ    normal     11.0
# 1         583          ra2         0       NON_SOZ    normal     11.0
# 2         583          ra3         0       NON_SOZ    normal     11.0
# 3         583          ra4         0       NON_SOZ    normal     11.0
# 4         583          ra5         0       NON_SOZ    normal     11.0
#
#    HFO_65.0-80.0  HFO_80.0-250.0  HFO_250.0-600.0  spike_rate  ...  \
# 0              0              11               34          22  ...
# 1              0              16               40          49  ...
# 2              0              20               35          61  ...
# 3              0              27               37          66  ...
# 4              0              11               58          63  ...
#
#    coherence_80.0-250.0  lin_corr_median_250.0-600.0  ren_250.0-600.0  \
# 0              0.997413                     0.990955         0.004121
# 1              0.998458                     0.993981         0.002847
# 2              0.999506                     0.996993         0.001647
# 3              0.999126                     0.995900         0.002311
# 4              0.997734                     0.995822         0.002367
#
#    phase_sync_250.0-600.0  phase_const_250.0-600.0  pli_250.0-600.0  \
# 0                0.970733                      1.0         0.815222
# 1                0.979349                      1.0         0.841924
# 2                0.987957                      1.0         0.857311
# 3                0.986385                      1.0         0.852814
# 4                0.986189                      1.0         0.861413
#
#    pli_tau_250.0-600.0  coherence_250.0-600.0  segm_type  segm_number
# 0            -0.146667               0.994151          0            0
# 1            -0.113333               0.996071          0            0
# 2            -0.043333               0.997980          0            0
# 3            -0.036667               0.997646          0            0
# 4            -0.058333               0.997589          0            0
#
# [5 rows x 96 columns]

# %%
# Basic statistics

epilepsy.describe()
# Out:
#          patient_id      resected       outcome  HFO_65.0-80.0  \
# count  92464.000000  92464.000000  92464.000000        92464.0
# mean     537.303340      0.121647     23.258695            0.0
# std      530.808972      0.326880     11.931679            0.0
# min       59.000000      0.000000     11.000000            0.0
# 25%       74.000000      0.000000     11.000000            0.0
# 50%       92.000000      0.000000     22.000000            0.0
# 75%     1021.000000      0.000000     31.000000            0.0
# max     1718.000000      1.000000     42.000000            0.0
#
#        HFO_80.0-250.0  HFO_250.0-600.0    spike_rate  power_1.0-4.0  \
# count    92464.000000     92464.000000  92464.000000   9.185100e+04
# mean        18.444627        32.607555     19.159565   3.177411e-01
# std         18.584647        39.284876     37.979718   5.231405e-01
# min          0.000000         0.000000      0.000000   2.364873e-09
# 25%          5.000000         5.000000      1.000000   4.768943e-06
# 50%         13.000000        17.000000      6.000000   1.325354e-01
# 75%         26.000000        45.000000     20.000000   4.901011e-01
# max        157.000000       335.000000    904.000000   1.649692e+01
#
#        power_4.0-8.0  power_8.0-12.0  ...  coherence_80.0-250.0  \
# count   9.185100e+04    9.185100e+04  ...          84751.000000
# mean    2.887090e-01    2.387289e-01  ...              0.921873
# std     5.700138e-01    4.831948e-01  ...              0.079289
# min     5.991072e-10    1.304421e-10  ...              0.413911
# 25%     1.300755e-06    4.188223e-07  ...              0.843208
# 50%     6.279375e-02    2.494825e-02  ...              0.962194
# 75%     3.697457e-01    2.872959e-01  ...              0.997170
# max     1.779064e+01    1.057295e+01  ...              1.000000
#
#        lin_corr_median_250.0-600.0  ren_250.0-600.0  phase_sync_250.0-600.0  \
# count                 84751.000000     84751.000000            84751.000000
# mean                      0.710600         0.030662                0.663745
# std                       0.308275         0.036740                0.324243
# min                      -0.628716         0.000013                0.044833
# 25%                       0.372571         0.005341                0.301537
# 50%                       0.920298         0.022501                0.856442
# 75%                       0.988867         0.047192                0.967804
# max                       0.999997         1.034580                0.999998
#
#        phase_const_250.0-600.0  pli_250.0-600.0  pli_tau_250.0-600.0  \
# count             84751.000000     84751.000000         84751.000000
# mean                  0.041663         0.035568            -0.002958
# std                   0.199820         0.171318             0.031019
# min                   0.000000         0.000000            -0.706667
# 25%                   0.000000         0.000000             0.000000
# 50%                   0.000000         0.000000             0.000000
# 75%                   0.000000         0.000000             0.000000
# max                   1.000000         0.999540             0.356667
#
#        coherence_250.0-600.0     segm_type   segm_number
# count           84751.000000  92464.000000  92464.000000
# mean                0.899877      6.250000      0.562500
# std                 0.097597      4.548376      0.788099
# min                 0.645227      0.000000      0.000000
# 25%                 0.787374      1.750000      0.000000
# 50%                 0.956153      8.000000      0.000000
# 75%                 0.993218     10.250000      1.000000
# max                 0.999999     12.000000      2.000000
#
# [8 rows x 93 columns]

# %%
# Correlatin matrix + rounding

corrmat = epilepsy.corr()
#pd.options.display.float_format = '{:.3f}'.format
corrmat.round(3)
# Out:
#                        patient_id  resected  outcome  HFO_65.0-80.0  \
# patient_id                  1.000     0.166   -0.043            NaN
# resected                    0.166     1.000    0.016            NaN
# outcome                    -0.043     0.016    1.000            NaN
# HFO_65.0-80.0                 NaN       NaN      NaN            NaN
# HFO_80.0-250.0             -0.020     0.245    0.016            NaN
# ...                           ...       ...      ...            ...
# pli_250.0-600.0            -0.002     0.056   -0.032            NaN
# pli_tau_250.0-600.0         0.011    -0.082   -0.030            NaN
# coherence_250.0-600.0       0.821     0.152    0.008            NaN
# segm_type                  -0.000    -0.000    0.000            NaN
# segm_number                 0.000    -0.000    0.000            NaN
#
#                        HFO_80.0-250.0  HFO_250.0-600.0  spike_rate  \
# patient_id                     -0.020            0.184      -0.056
# resected                        0.245            0.133       0.244
# outcome                         0.016            0.012      -0.025
# HFO_65.0-80.0                     NaN              NaN         NaN
# HFO_80.0-250.0                  1.000            0.429       0.653
# ...                               ...              ...         ...
# pli_250.0-600.0                -0.035            0.058       0.028
# pli_tau_250.0-600.0             0.040           -0.021      -0.009
# coherence_250.0-600.0          -0.032            0.255      -0.061
# segm_type                       0.008           -0.032       0.005
# segm_number                     0.008            0.082      -0.009
#
#                        power_1.0-4.0  power_4.0-8.0  power_8.0-12.0  ...  \
# patient_id                     0.510          0.428           0.407  ...
# resected                       0.097          0.041           0.035  ...
# outcome                        0.063         -0.010          -0.062  ...
# HFO_65.0-80.0                    NaN            NaN             NaN  ...
# HFO_80.0-250.0                 0.006         -0.046          -0.062  ...
# ...                              ...            ...             ...  ...
# pli_250.0-600.0                0.065          0.112           0.151  ...
# pli_tau_250.0-600.0           -0.014         -0.029          -0.083  ...
# coherence_250.0-600.0          0.506          0.452           0.456  ...
# segm_type                     -0.022         -0.027          -0.039  ...
# segm_number                   -0.001          0.008           0.022  ...
#
#                        coherence_80.0-250.0  lin_corr_median_250.0-600.0  \
# patient_id                            0.796                        0.798
# resected                              0.140                        0.149
# outcome                               0.028                        0.016
# HFO_65.0-80.0                           NaN                          NaN
# HFO_80.0-250.0                       -0.024                       -0.023
# ...                                     ...                          ...
# pli_250.0-600.0                       0.185                        0.183
# pli_tau_250.0-600.0                  -0.090                       -0.087
# coherence_250.0-600.0                 0.921                        0.990
# segm_type                             0.008                        0.034
# segm_number                           0.021                        0.014
#
#                        ren_250.0-600.0  phase_sync_250.0-600.0  \
# patient_id                      -0.570                   0.823
# resected                        -0.047                   0.154
# outcome                         -0.020                   0.012
# HFO_65.0-80.0                      NaN                     NaN
# HFO_80.0-250.0                   0.256                  -0.027
# ...                                ...                     ...
# pli_250.0-600.0                 -0.139                   0.193
# pli_tau_250.0-600.0              0.072                  -0.095
# coherence_250.0-600.0           -0.640                   0.998
# segm_type                        0.013                   0.028
# segm_number                     -0.012                   0.014
#
#                        phase_const_250.0-600.0  pli_250.0-600.0  \
# patient_id                              -0.001           -0.002
# resected                                 0.047            0.056
# outcome                                 -0.042           -0.032
# HFO_65.0-80.0                              NaN              NaN
# HFO_80.0-250.0                          -0.033           -0.035
# ...                                        ...              ...
# pli_250.0-600.0                          0.996            1.000
# pli_tau_250.0-600.0                     -0.457           -0.502
# coherence_250.0-600.0                    0.192            0.193
# segm_type                               -0.004           -0.005
# segm_number                             -0.030           -0.028
#
#                        pli_tau_250.0-600.0  coherence_250.0-600.0  segm_type  \
# patient_id                           0.011                  0.821     -0.000
# resected                            -0.082                  0.152     -0.000
# outcome                             -0.030                  0.008      0.000
# HFO_65.0-80.0                          NaN                    NaN        NaN
# HFO_80.0-250.0                       0.040                 -0.032      0.008
# ...                                    ...                    ...        ...
# pli_250.0-600.0                     -0.502                  0.193     -0.005
# pli_tau_250.0-600.0                  1.000                 -0.094     -0.012
# coherence_250.0-600.0               -0.094                  1.000      0.031
# segm_type                           -0.012                  0.031      1.000
# segm_number                          0.022                  0.011      0.065
#
#                        segm_number
# patient_id                   0.000
# resected                    -0.000
# outcome                      0.000
# HFO_65.0-80.0                  NaN
# HFO_80.0-250.0               0.008
# ...                            ...
# pli_250.0-600.0             -0.028
# pli_tau_250.0-600.0          0.022
# coherence_250.0-600.0        0.011
# segm_type                    0.065
# segm_number                  1.000
#
# [93 rows x 93 columns]

# %%
# Correlation matrix heatmap

sns.heatmap(corrmat);

# %%
# Columns names

cols = epilepsy.columns
print(list(cols))
# Out:
# ['patient_id', 'channel_name', 'resected', 'onset_channel', 'pathology', 'outcome', 'HFO_65.0-80.0', 'HFO_80.0-250.0', 'HFO_250.0-600.0', 'spike_rate', 'power_1.0-4.0', 'power_4.0-8.0', 'power_8.0-12.0', 'power_12.0-20.0', 'power_20.0-45.0', 'power_65.0-80.0', 'power_80.0-250.0', 'power_250.0-600.0', 'hlx_0.0-0.0', 'hlx_1.0-4.0', 'hlx_4.0-8.0', 'hlx_8.0-12.0', 'hlx_12.0-20.0', 'hlx_20.0-45.0', 'hlx_65.0-80.0', 'hlx_80.0-250.0', 'hlx_250.0-600.0', 'pse', 'pac', 'fac', 'lfr', 'lin_corr_median_0.0-0.0', 'ren_0.0-0.0', 'phase_sync_0.0-0.0', 'phase_const_0.0-0.0', 'pli_0.0-0.0', 'pli_tau_0.0-0.0', 'coherence_0.0-0.0', 'lin_corr_median_1.0-4.0', 'ren_1.0-4.0', 'phase_sync_1.0-4.0', 'phase_const_1.0-4.0', 'pli_1.0-4.0', 'pli_tau_1.0-4.0', 'coherence_1.0-4.0', 'lin_corr_median_4.0-8.0', 'ren_4.0-8.0', 'phase_sync_4.0-8.0', 'phase_const_4.0-8.0', 'pli_4.0-8.0', 'pli_tau_4.0-8.0', 'coherence_4.0-8.0', 'lin_corr_median_8.0-12.0', 'ren_8.0-12.0', 'phase_sync_8.0-12.0', 'phase_const_8.0-12.0', 'pli_8.0-12.0', 'pli_tau_8.0-12.0', 'coherence_8.0-12.0', 'lin_corr_median_12.0-20.0', 'ren_12.0-20.0', 'phase_sync_12.0-20.0', 'phase_const_12.0-20.0', 'pli_12.0-20.0', 'pli_tau_12.0-20.0', 'coherence_12.0-20.0', 'lin_corr_median_20.0-45.0', 'ren_20.0-45.0', 'phase_sync_20.0-45.0', 'phase_const_20.0-45.0', 'pli_20.0-45.0', 'pli_tau_20.0-45.0', 'coherence_20.0-45.0', 'lin_corr_median_65.0-80.0', 'ren_65.0-80.0', 'phase_sync_65.0-80.0', 'phase_const_65.0-80.0', 'pli_65.0-80.0', 'pli_tau_65.0-80.0', 'coherence_65.0-80.0', 'lin_corr_median_80.0-250.0', 'ren_80.0-250.0', 'phase_sync_80.0-250.0', 'phase_const_80.0-250.0', 'pli_80.0-250.0', 'pli_tau_80.0-250.0', 'coherence_80.0-250.0', 'lin_corr_median_250.0-600.0', 'ren_250.0-600.0', 'phase_sync_250.0-600.0', 'phase_const_250.0-600.0', 'pli_250.0-600.0', 'pli_tau_250.0-600.0', 'coherence_250.0-600.0', 'segm_type', 'segm_number']

# %%
# Split epilepsy dataset to Montreal & Brno dataframe

df_montreal, df_brno = [x for _, x in epilepsy.groupby(epilepsy['patient_id'] < 100)]

# %%
# Onset channels countplots

fig, ax = plt.subplots(1,3, figsize = (20, 7))

sns.countplot('onset_channel', data = df_brno, ax = ax[0])
ax[0].title.set_text('Brno Onset Channel')

sns.countplot('onset_channel', data = df_montreal, ax = ax[1])
ax[1].title.set_text('Montreal Onset Channel')

sns.countplot('onset_channel', data = epilepsy, ax = ax[2])
ax[2].title.set_text('Overall Onset Channel')

#epilepsy['onset_channel'].value_counts()
#epilepsy['onset_channel'].value_counts().plot.pie(autopct = '%1.2f%%');

plt.show()

# %%
# Resected countplots

fig, ax = plt.subplots(1,3, figsize = (20, 7))

sns.countplot('resected', data = df_brno, ax = ax[0])
ax[0].title.set_text('Brno Resected')

sns.countplot('resected', data = df_montreal, ax = ax[1])
ax[1].title.set_text('Montreal Resected')

sns.countplot('resected', data = epilepsy, ax = ax[2])
ax[2].title.set_text('Overall Resected')

plt.show()

# %%
# Pathology countplot

fig, ax = plt.subplots(1,3, figsize = (20, 7))

sns.countplot('pathology', data = df_brno, ax = ax[0])
ax[0].title.set_text('Brno Pathology')

sns.countplot('pathology', data = df_montreal, ax = ax[1])
ax[1].title.set_text('Montreal Pathology')

sns.countplot('pathology', data = epilepsy, ax = ax[2])
ax[2].title.set_text('Overall Pathology')

plt.show()

# %%
# Brno oucome countplot

sns.countplot('outcome', data = df_brno);

# %%
# Montreal oucome countplot

sns.countplot('outcome', data = df_montreal);

# %%
# Overall oucome countplot

sns.countplot('outcome', data = epilepsy);
#sns.distplot(epilepsy['outcome']);
#sns.kdeplot(epilepsy['outcome'], shade = True);

# %%
# Overall outcome KDE plot 

sns.kdeplot(epilepsy['outcome'], shade = True);

# %%
# Country column

epilepsy.loc[epilepsy['patient_id'] < 100 , 'country'] = 'Brno' 
epilepsy.loc[epilepsy['patient_id'] > 100 , 'country'] = 'Montreal' 
epilepsy.head()
# Out:
#    patient_id channel_name  resected onset_channel pathology  outcome  \
# 0         583          ra1         0       NON_SOZ    normal     11.0
# 1         583          ra2         0       NON_SOZ    normal     11.0
# 2         583          ra3         0       NON_SOZ    normal     11.0
# 3         583          ra4         0       NON_SOZ    normal     11.0
# 4         583          ra5         0       NON_SOZ    normal     11.0
#
#    HFO_65.0-80.0  HFO_80.0-250.0  HFO_250.0-600.0  spike_rate  ...  \
# 0              0              11               34          22  ...
# 1              0              16               40          49  ...
# 2              0              20               35          61  ...
# 3              0              27               37          66  ...
# 4              0              11               58          63  ...
#
#    lin_corr_median_250.0-600.0  ren_250.0-600.0  phase_sync_250.0-600.0  \
# 0                     0.990955         0.004121                0.970733
# 1                     0.993981         0.002847                0.979349
# 2                     0.996993         0.001647                0.987957
# 3                     0.995900         0.002311                0.986385
# 4                     0.995822         0.002367                0.986189
#
#    phase_const_250.0-600.0  pli_250.0-600.0  pli_tau_250.0-600.0  \
# 0                      1.0         0.815222            -0.146667
# 1                      1.0         0.841924            -0.113333
# 2                      1.0         0.857311            -0.043333
# 3                      1.0         0.852814            -0.036667
# 4                      1.0         0.861413            -0.058333
#
#    coherence_250.0-600.0  segm_type  segm_number   country
# 0               0.994151          0            0  Montreal
# 1               0.996071          0            0  Montreal
# 2               0.997980          0            0  Montreal
# 3               0.997646          0            0  Montreal
# 4               0.997589          0            0  Montreal
#
# [5 rows x 97 columns]

# %%
# Onset channels in numbers

epilepsy.groupby(['country', 'onset_channel'])['onset_channel'].count()
# Out:
# country   onset_channel
# Brno      NON_SOZ          46784
#           SOZ               2112
# Montreal  NON_SOZ          35888
#           SOZ               7680
# Name: onset_channel, dtype: int64

# %%
# Resected in numbers

epilepsy.groupby(['country', 'resected'])['resected'].count()
# Out:
# country   resected
# Brno      0           45728
#           1            3168
# Montreal  0           35488
#           1            8080
# Name: resected, dtype: int64

# %%
# Pathology in numbers

epilepsy.groupby(['country', 'pathology'])['pathology'].count()
# Out:
# country   pathology
# Brno      normal        46784
#           pathologic     2112
# Montreal  normal        35888
#           pathologic     7680
# Name: pathology, dtype: int64

# %%
# Country countplot

sns.countplot('country', data = epilepsy);

# %%
# Country in numbers

epilepsy['country'].value_counts()
# Out:
# Brno        48896
# Montreal    43568
# Name: country, dtype: int64

# %%
# Number of patients

epilepsy['patient_id'].nunique()
# Out:
# 53

# %%
# Number of patients in Brno

df_brno['patient_id'].nunique()
# Out:
# 19

# %%
# Number of patients in Montreal

df_montreal['patient_id'].nunique()
# Out:
# 34

# %%
# Number of unique channel names 

epilepsy['channel_name'].nunique()
# Out:
# 1740

# %%
# Number of outcome per country

epilepsy.groupby(['country', 'outcome'])['outcome'].count()
# Out:
# country   outcome
# Brno      11.0       16368
#           12.0        2768
#           21.0        2800
#           22.0        2784
#           31.0       18912
#           41.0        2800
#           42.0        2464
# Montreal  11.0       15008
#           12.0        6064
#           14.0        1648
#           21.0         912
#           22.0         912
#           31.0        5376
#           32.0        1808
#           41.0        9216
#           42.0        2624
# Name: outcome, dtype: int64

# %%
# Number of spike rates 

epilepsy['spike_rate'].nunique()
# Out:
# 429

# %%
# Number of segm_type per country

epilepsy.groupby(['country', 'segm_type'])['segm_type'].count()
# Out:
# country   segm_type
# Brno      0            9168
#           1            3056
#           2            3056
#           3            3056
#           4            3056
#           8            9168
#           9            3056
#           10           3056
#           11           3056
#           12           9168
# Montreal  0            8169
#           1            2723
#           2            2723
#           3            2723
#           4            2723
#           8            8169
#           9            2723
#           10           2723
#           11           2723
#           12           8169
# Name: segm_type, dtype: int64

# %%
# Overall segm type countplot 

sns.countplot('segm_type', data = epilepsy);

# %%
# Onset channels, resected, pathology countplots

fig, ax = plt.subplots(1,3, figsize = (20, 7))

sns.countplot('country', data = epilepsy, hue = 'onset_channel', ax = ax[0] );
sns.countplot('country', data = epilepsy, hue = 'resected', ax = ax[1] );
sns.countplot('country', data = epilepsy, hue = 'pathology', ax = ax[2] );

plt.show()

# %%
# Overall outcome per country catplot 

sns.catplot(x = 'country', y = 'resected', kind = 'point', data = epilepsy, hue = 'outcome');

# %%
# Elipepsy dataframe with datatypes

epilepsy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92464 entries, 0 to 92463
# Data columns (total 97 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   patient_id                   92464 non-null  int64
#  1   channel_name                 92464 non-null  object
#  2   resected                     92464 non-null  int64
#  3   onset_channel                92464 non-null  object
#  4   pathology                    92464 non-null  object
#  5   outcome                      92464 non-null  float64
#  6   HFO_65.0-80.0                92464 non-null  int64
#  7   HFO_80.0-250.0               92464 non-null  int64
#  8   HFO_250.0-600.0              92464 non-null  int64
#  9   spike_rate                   92464 non-null  int64
#  10  power_1.0-4.0                91851 non-null  float64
#  11  power_4.0-8.0                91851 non-null  float64
#  12  power_8.0-12.0               91851 non-null  float64
#  13  power_12.0-20.0              91851 non-null  float64
#  14  power_20.0-45.0              91851 non-null  float64
#  15  power_65.0-80.0              91851 non-null  float64
#  16  power_80.0-250.0             91851 non-null  float64
#  17  power_250.0-600.0            91851 non-null  float64
#  18  hlx_0.0-0.0                  91851 non-null  float64
#  19  hlx_1.0-4.0                  91851 non-null  float64
#  20  hlx_4.0-8.0                  91851 non-null  float64
#  21  hlx_8.0-12.0                 91851 non-null  float64
#  22  hlx_12.0-20.0                91851 non-null  float64
#  23  hlx_20.0-45.0                91851 non-null  float64
#  24  hlx_65.0-80.0                91851 non-null  float64
#  25  hlx_80.0-250.0               91851 non-null  float64
#  26  hlx_250.0-600.0              91851 non-null  float64
#  27  pse                          91851 non-null  float64
#  28  pac                          91851 non-null  float64
#  29  fac                          91851 non-null  float64
#  30  lfr                          91851 non-null  float64
#  31  lin_corr_median_0.0-0.0      84751 non-null  float64
#  32  ren_0.0-0.0                  84751 non-null  float64
#  33  phase_sync_0.0-0.0           84751 non-null  float64
#  34  phase_const_0.0-0.0          84751 non-null  float64
#  35  pli_0.0-0.0                  84751 non-null  float64
#  36  pli_tau_0.0-0.0              84751 non-null  float64
#  37  coherence_0.0-0.0            84751 non-null  float64
#  38  lin_corr_median_1.0-4.0      84751 non-null  float64
#  39  ren_1.0-4.0                  84751 non-null  float64
#  40  phase_sync_1.0-4.0           84751 non-null  float64
#  41  phase_const_1.0-4.0          84751 non-null  float64
#  42  pli_1.0-4.0                  84751 non-null  float64
#  43  pli_tau_1.0-4.0              84751 non-null  float64
#  44  coherence_1.0-4.0            84751 non-null  float64
#  45  lin_corr_median_4.0-8.0      84751 non-null  float64
#  46  ren_4.0-8.0                  84751 non-null  float64
#  47  phase_sync_4.0-8.0           84751 non-null  float64
#  48  phase_const_4.0-8.0          84751 non-null  float64
#  49  pli_4.0-8.0                  84751 non-null  float64
#  50  pli_tau_4.0-8.0              84751 non-null  float64
#  51  coherence_4.0-8.0            84751 non-null  float64
#  52  lin_corr_median_8.0-12.0     84751 non-null  float64
#  53  ren_8.0-12.0                 84751 non-null  float64
#  54  phase_sync_8.0-12.0          84751 non-null  float64
#  55  phase_const_8.0-12.0         84751 non-null  float64
#  56  pli_8.0-12.0                 84751 non-null  float64
#  57  pli_tau_8.0-12.0             84751 non-null  float64
#  58  coherence_8.0-12.0           84751 non-null  float64
#  59  lin_corr_median_12.0-20.0    84751 non-null  float64
#  60  ren_12.0-20.0                84751 non-null  float64
#  61  phase_sync_12.0-20.0         84751 non-null  float64
#  62  phase_const_12.0-20.0        84751 non-null  float64
#  63  pli_12.0-20.0                84751 non-null  float64
#  64  pli_tau_12.0-20.0            84751 non-null  float64
#  65  coherence_12.0-20.0          84751 non-null  float64
#  66  lin_corr_median_20.0-45.0    84751 non-null  float64
#  67  ren_20.0-45.0                84751 non-null  float64
#  68  phase_sync_20.0-45.0         84751 non-null  float64
#  69  phase_const_20.0-45.0        84751 non-null  float64
#  70  pli_20.0-45.0                84751 non-null  float64
#  71  pli_tau_20.0-45.0            84751 non-null  float64
#  72  coherence_20.0-45.0          84751 non-null  float64
#  73  lin_corr_median_65.0-80.0    84751 non-null  float64
#  74  ren_65.0-80.0                84751 non-null  float64
#  75  phase_sync_65.0-80.0         84751 non-null  float64
#  76  phase_const_65.0-80.0        84751 non-null  float64
#  77  pli_65.0-80.0                84751 non-null  float64
#  78  pli_tau_65.0-80.0            84751 non-null  float64
#  79  coherence_65.0-80.0          84751 non-null  float64
#  80  lin_corr_median_80.0-250.0   84751 non-null  float64
#  81  ren_80.0-250.0               84751 non-null  float64
#  82  phase_sync_80.0-250.0        84751 non-null  float64
#  83  phase_const_80.0-250.0       84751 non-null  float64
#  84  pli_80.0-250.0               84751 non-null  float64
#  85  pli_tau_80.0-250.0           84751 non-null  float64
#  86  coherence_80.0-250.0         84751 non-null  float64
#  87  lin_corr_median_250.0-600.0  84751 non-null  float64
#  88  ren_250.0-600.0              84751 non-null  float64
#  89  phase_sync_250.0-600.0       84751 non-null  float64
#  90  phase_const_250.0-600.0      84751 non-null  float64
#  91  pli_250.0-600.0              84751 non-null  float64
#  92  pli_tau_250.0-600.0          84751 non-null  float64
#  93  coherence_250.0-600.0        84751 non-null  float64
#  94  segm_type                    92464 non-null  int64
#  95  segm_number                  92464 non-null  int64
#  96  country                      92464 non-null  object
# dtypes: float64(85), int64(8), object(4)
# memory usage: 68.4+ MB

# %%
# Drop columns no. 0, 1, and 6

df_epilepsy = epilepsy.drop(epilepsy.columns[[0, 1, 2, 5, 6]], axis=1)
df_brno = df_brno.drop(df_brno.columns[[0, 1, 2, 5, 6]], axis=1)
df_montreal = df_montreal.drop(df_montreal.columns[[0, 1, 2, 5, 6]], axis=1)

# %%
# Start H2o

import h2o 
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         44 mins 27 secs
# H2O_cluster_timezone:       Europe/Prague
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.2
# H2O_cluster_version_age:    1 month and 13 days
# H2O_cluster_name:           H2O_from_python_Rodina_r7fxce
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.381 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.7.3 final
# --------------------------  -----------------------------

# %%
# Parse dataframe df_brno to H2o

h2o_df = h2o.H2OFrame(df_brno)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
# Dataframe summary describe

h2o_df.describe()
# Out:
# Rows:48896
# Cols:91
# <table>
# <thead>
# <tr><th>       </th><th>onset_channel  </th><th>pathology  </th><th>HFO_80.0-250.0    </th><th>HFO_250.0-600.0   </th><th>spike_rate        </th><th>power_1.0-4.0        </th><th>power_4.0-8.0        </th><th>power_8.0-12.0       </th><th>power_12.0-20.0       </th><th>power_20.0-45.0      </th><th>power_65.0-80.0       </th><th>power_80.0-250.0      </th><th>power_250.0-600.0     </th><th>hlx_0.0-0.0       </th><th>hlx_1.0-4.0         </th><th>hlx_4.0-8.0        </th><th>hlx_8.0-12.0         </th><th>hlx_12.0-20.0        </th><th>hlx_20.0-45.0      </th><th>hlx_65.0-80.0         </th><th>hlx_80.0-250.0      </th><th>hlx_250.0-600.0     </th><th>pse                   </th><th>pac                  </th><th>fac                  </th><th>lfr               </th><th>lin_corr_median_0.0-0.0  </th><th>ren_0.0-0.0        </th><th>phase_sync_0.0-0.0  </th><th>phase_const_0.0-0.0  </th><th>pli_0.0-0.0  </th><th>pli_tau_0.0-0.0  </th><th>coherence_0.0-0.0   </th><th>lin_corr_median_1.0-4.0  </th><th>ren_1.0-4.0        </th><th>phase_sync_1.0-4.0  </th><th>phase_const_1.0-4.0  </th><th>pli_1.0-4.0  </th><th>pli_tau_1.0-4.0  </th><th>coherence_1.0-4.0  </th><th>lin_corr_median_4.0-8.0  </th><th>ren_4.0-8.0        </th><th>phase_sync_4.0-8.0  </th><th>phase_const_4.0-8.0  </th><th>pli_4.0-8.0  </th><th>pli_tau_4.0-8.0  </th><th>coherence_4.0-8.0  </th><th>lin_corr_median_8.0-12.0  </th><th>ren_8.0-12.0        </th><th>phase_sync_8.0-12.0  </th><th>phase_const_8.0-12.0  </th><th>pli_8.0-12.0  </th><th>pli_tau_8.0-12.0  </th><th>coherence_8.0-12.0  </th><th>lin_corr_median_12.0-20.0  </th><th>ren_12.0-20.0      </th><th>phase_sync_12.0-20.0  </th><th>phase_const_12.0-20.0  </th><th>pli_12.0-20.0  </th><th>pli_tau_12.0-20.0  </th><th>coherence_12.0-20.0  </th><th>lin_corr_median_20.0-45.0  </th><th>ren_20.0-45.0      </th><th>phase_sync_20.0-45.0  </th><th>phase_const_20.0-45.0  </th><th>pli_20.0-45.0  </th><th>pli_tau_20.0-45.0  </th><th>coherence_20.0-45.0  </th><th>lin_corr_median_65.0-80.0  </th><th>ren_65.0-80.0      </th><th>phase_sync_65.0-80.0  </th><th>phase_const_65.0-80.0  </th><th>pli_65.0-80.0  </th><th>pli_tau_65.0-80.0  </th><th>coherence_65.0-80.0  </th><th>lin_corr_median_80.0-250.0  </th><th>ren_80.0-250.0     </th><th>phase_sync_80.0-250.0  </th><th>phase_const_80.0-250.0  </th><th>pli_80.0-250.0  </th><th>pli_tau_80.0-250.0  </th><th>coherence_80.0-250.0  </th><th>lin_corr_median_250.0-600.0  </th><th>ren_250.0-600.0    </th><th>phase_sync_250.0-600.0  </th><th>phase_const_250.0-600.0  </th><th>pli_250.0-600.0  </th><th>pli_tau_250.0-600.0  </th><th>coherence_250.0-600.0  </th><th>segm_type        </th><th>segm_number       </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>enum           </td><td>enum       </td><td>int               </td><td>int               </td><td>int               </td><td>real                 </td><td>real                 </td><td>real                 </td><td>real                  </td><td>real                 </td><td>real                  </td><td>real                  </td><td>real                  </td><td>real              </td><td>real                </td><td>real               </td><td>real                 </td><td>real                 </td><td>real               </td><td>real                  </td><td>real                </td><td>real                </td><td>real                  </td><td>real                 </td><td>real                 </td><td>real              </td><td>real                     </td><td>real               </td><td>real                </td><td>int                  </td><td>int          </td><td>int              </td><td>real                </td><td>real                     </td><td>real               </td><td>real                </td><td>int                  </td><td>int          </td><td>int              </td><td>real               </td><td>real                     </td><td>real               </td><td>real                </td><td>int                  </td><td>int          </td><td>int              </td><td>real               </td><td>real                      </td><td>real                </td><td>real                 </td><td>int                   </td><td>int           </td><td>int               </td><td>real                </td><td>real                       </td><td>real               </td><td>real                  </td><td>int                    </td><td>int            </td><td>int                </td><td>real                 </td><td>real                       </td><td>real               </td><td>real                  </td><td>int                    </td><td>int            </td><td>int                </td><td>real                 </td><td>real                       </td><td>real               </td><td>real                  </td><td>int                    </td><td>int            </td><td>int                </td><td>real                 </td><td>real                        </td><td>real               </td><td>real                   </td><td>int                     </td><td>int             </td><td>int                 </td><td>real                  </td><td>real                         </td><td>real               </td><td>real                    </td><td>int                      </td><td>int              </td><td>int                  </td><td>real                   </td><td>int              </td><td>int               </td></tr>
# <tr><td>mins   </td><td>               </td><td>           </td><td>0.0               </td><td>0.0               </td><td>0.0               </td><td>2.364873452899435e-09</td><td>5.991071834409485e-10</td><td>1.30442119819651e-10 </td><td>1.1681560430904823e-10</td><td>7.101002637861296e-11</td><td>2.7499975461833418e-12</td><td>9.00901396503794e-12  </td><td>1.791892948869557e-12 </td><td>1.9917711675167085</td><td>1.0429315082232158  </td><td>1.024207173784574  </td><td>1.009632244706154    </td><td>1.0169157228867214   </td><td>1.0255174605051676 </td><td>1.00433056751887      </td><td>1.0723376913865408  </td><td>1.0338828110694884  </td><td>4.1345508072694234e-08</td><td>-0.0301517782869955  </td><td>-0.0480698364421173  </td><td>0.0001713543694596</td><td>-0.60713068140205        </td><td>0.0007888324235439 </td><td>0.2648637568174551  </td><td>0.0                  </td><td>0.0          </td><td>0.0              </td><td>0.5318318547991414  </td><td>-0.6848305695938567      </td><td>0.0002853959685614 </td><td>0.4160011687564353  </td><td>0.0                  </td><td>0.0          </td><td>0.0              </td><td>0.8005658301711083 </td><td>-0.4964481848354141      </td><td>0.0002662190965012 </td><td>0.3625855857071777  </td><td>0.0                  </td><td>0.0          </td><td>0.0              </td><td>0.7670663423339525 </td><td>-0.6718678639518718       </td><td>0.0001387444527563  </td><td>0.3679261469530562   </td><td>0.0                   </td><td>0.0           </td><td>0.0               </td><td>0.8077897173166275  </td><td>-0.5553509854665026        </td><td>0.0003144570361367 </td><td>0.2741534049808979    </td><td>0.0                    </td><td>0.0            </td><td>0.0                </td><td>0.7843798479437828   </td><td>-0.5645505384852488        </td><td>0.0013636277488512 </td><td>0.0709188060369342    </td><td>0.0                    </td><td>0.0            </td><td>0.0                </td><td>0.3186498494446277   </td><td>-0.4347636483931759        </td><td>0.0004002587928456 </td><td>0.1924236926358814    </td><td>0.0                    </td><td>0.0            </td><td>0.0                </td><td>0.787879088918368    </td><td>-0.8790900172789892         </td><td>0.0004151352456028 </td><td>0.0749742081714794     </td><td>0.0                     </td><td>0.0             </td><td>0.0                 </td><td>0.4139111252129078    </td><td>-0.6287160007655621          </td><td>0.0005872322634589 </td><td>0.0448328197945375      </td><td>0.0                      </td><td>0.0              </td><td>0.0                  </td>

# %%
# Split train and test sets

train, test = h2o_df.split_frame(ratios=[.75], seed=121)

# Define X and y

X = train.columns
y = 'pathology'
X.remove(y)

# %%
# For binary classification, response should be a factor

train[y] = train[y].asfactor()
test[y] = test[y].asfactor()
y
# Out:
# 'pathology'

# %%
# Review dataframe if balanced or not 

df_brno.pathology.value_counts()
# Out:
# normal        46784
# pathologic     2112
# Name: pathology, dtype: int64

# %%
# Import H2o AutoML

from h2o.automl import H2OAutoML

# %%
# Run H2o AutoML for 600 secs = 10 minutes

aml = H2OAutoML(max_runtime_secs=600,   
                balance_classes=True,
                stopping_metric='AUC',
                seed=121) 


# %time aml.train(x=X, y=y, training_frame = train)
# Out:
# AutoML progress: |█
# 10:49:10.189: AutoML: XGBoost is not available; skipping it.
# 10:49:10.205: _train param, Dropping bad and constant columns: [pli_250.0-600.0, phase_const_250.0-600.0, pli_tau_0.0-0.0, pli_tau_250.0-600.0, pli_tau_12.0-20.0, phase_const_20.0-45.0, pli_65.0-80.0, phase_const_80.0-250.0, pli_0.0-0.0, pli_tau_20.0-45.0, phase_const_0.0-0.0, phase_const_4.0-8.0, pli_tau_65.0-80.0, pli_20.0-45.0, phase_const_1.0-4.0, phase_const_12.0-20.0, pli_tau_80.0-250.0, pli_12.0-20.0, pli_tau_8.0-12.0, pli_4.0-8.0, phase_const_8.0-12.0, phase_const_65.0-80.0, pli_8.0-12.0, pli_80.0-250.0, pli_tau_4.0-8.0, pli_tau_1.0-4.0, pli_1.0-4.0]
#
# █████████████████████████
# 10:52:57.72: XRT_1_AutoML_2_20220710_104910 [DRF XRT (Extremely Randomized Trees)] failed: java.lang.AssertionError
#
# ██
# 10:53:22.391: _train param, Dropping bad and constant columns: [pli_250.0-600.0, phase_const_250.0-600.0, pli_tau_0.0-0.0, pli_tau_250.0-600.0, pli_tau_12.0-20.0, phase_const_20.0-45.0, pli_65.0-80.0, phase_const_80.0-250.0, pli_0.0-0.0, pli_tau_20.0-45.0, phase_const_0.0-0.0, phase_const_4.0-8.0, pli_tau_65.0-80.0, pli_20.0-45.0, phase_const_1.0-4.0, phase_const_12.0-20.0, pli_tau_80.0-250.0, pli_12.0-20.0, pli_tau_8.0-12.0, pli_4.0-8.0, phase_const_8.0-12.0, phase_const_65.0-80.0, pli_8.0-12.0, pli_80.0-250.0, pli_tau_4.0-8.0, pli_tau_1.0-4.0, pli_1.0-4.0]
#
# ███████████████████████████████████| (done) 100%
# Wall time: 10min 59s
# Model Details
# =============
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  GBM_4_AutoML_2_20220710_104910
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0               30.0                      30.0             129905.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0        1.0       10.0         7.3         2.0       595.0        340.7
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.07950129472891927
# RMSE: 0.28195973955321935
# LogLoss: 0.25478706562709746
# Mean Per-Class Error: 0.0
# AUC: 1.0
# AUCPR: 1.0
# Gini: 1.0
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4351927410209715:
#                 normal  pathologic Error            Rate
# 0      normal  35102.0         0.0   0.0   (0.0/35102.0)
# 1  pathologic      0.0     35095.0   0.0   (0.0/35095.0)
# 2       Total  35102.0     35095.0   0.0   (0.0/70197.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.435193      1.000000  373.0
# 1                        max f2   0.435193      1.000000  373.0
# 2                  max f0point5   0.435193      1.000000  373.0
# 3                  max accuracy   0.435193      1.000000  373.0
# 4                 max precision   0.643432      1.000000    0.0
# 5                    max recall   0.435193      1.000000  373.0
# 6               max specificity   0.643432      1.000000    0.0
# 7              max absolute_mcc   0.435193      1.000000  373.0
# 8    max min_per_class_accuracy   0.435193      1.000000  373.0
# 9   max mean_per_class_accuracy   0.435193      1.000000  373.0
# 10                      max tns   0.643432  35102.000000    0.0
# 11                      max fns   0.643432  35073.000000    0.0
# 12                      max fps   0.001112  35102.000000  399.0
# 13                      max tps   0.435193  35095.000000  373.0
# 14                      max tnr   0.643432      1.000000    0.0
# 15                      max fnr   0.643432      0.999373    0.0
# 16                      max fpr   0.001112      1.000000  399.0
# 17                      max tpr   0.435193      1.000000  373.0
# Gains/Lift Table: Avg response rate: 50.00 %, avg score: 30.18 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010086         0.633832  2.000199
# 1       2                  0.020143         0.632387  2.000199
# 2       3                  0.030243         0.630840  2.000199
# 3       4                  0.040002         0.629025  2.000199
# 4       5                  0.050059         0.628023  2.000199
# 5       6                  0.100090         0.622836  2.000199
# 6       7                  0.150049         0.619086  2.000199
# 7       8                  0.200023         0.615838  2.000199
# 8       9                  0.300283         0.607892  2.000199
# 9      10                  0.400188         0.583641  2.000199
# 10     11                  0.500007         0.002908  1.999058
# 11     12                  0.599997         0.001546  0.000000
# 12     13                  0.700001         0.001316  0.000000
# 13     14                  0.799991         0.001200  0.000000
# 14     15                  0.899996         0.001137  0.000000
# 15     16                  1.000000         0.001080  0.000000
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          2.000199       1.000000  0.636529                  1.000000
# 1          2.000199       1.000000  0.633574                  1.000000
# 2          2.000199       1.000000  0.631527                  1.000000
# 3          2.000199       1.000000  0.629822                  1.000000
# 4          2.000199       1.000000  0.628732                  1.000000
# 5          2.000199       1.000000  0.624934                  1.000000
# 6          2.000199       1.000000  0.620789                  1.000000
# 7          2.000199       1.000000  0.617791                  1.000000
# 8          2.000199       1.000000  0.611995                  1.000000
# 9          2.000199       1.000000  0.598022                  1.000000
# 10         1.999972       0.999429  0.553342                  0.999886
# 11         1.666675       0.000000  0.001917                  0.833254
# 12         1.428569       0.000000  0.001412                  0.714213
# 13         1.250013       0.000000  0.001258                  0.624944
# 14         1.111116       0.000000  0.001165                  0.555503
# 15         1.000000       0.000000  0.001117                  0.499950
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.636529      0.020174                 0.020174  100.019946
# 1           0.635054      0.020117                 0.040291  100.019946
# 2           0.633876      0.020202                 0.060493  100.019946
# 3           0.632887      0.019518                 0.080011  100.019946
# 4           0.632052      0.020117                 0.100128  100.019946
# 5           0.628494      0.100071                 0.200199  100.019946
# 6           0.625929      0.099929                 0.300128  100.019946
# 7           0.623896      0.099957                 0.400085  100.019946
# 8           0.619922      0.200541                 0.600627  100.019946
# 9           0.614455      0.199829                 0.800456  100.019946
# 10          0.602255      0.199544                 1.000000   99.905763
# 11          0.502208      0.000000                 1.000000 -100.000000
# 12          0.430663      0.000000                 1.000000 -100.000000
# 13          0.376992      0.000000                 1.000000 -100.000000
# 14          0.335231      0.000000                 1.000000 -100.000000
# 15          0.301819      0.000000                 1.000000 -100.000000
#
#     cumulative_gain  kolmogorov_smirnov
# 0        100.019946            0.020174
# 1        100.019946            0.040291
# 2        100.019946            0.060493
# 3        100.019946            0.080011
# 4        100.019946            0.100128
# 5        100.019946            0.200199
# 6        100.019946            0.300128
# 7        100.019946            0.400085
# 8        100.019946            0.600627
# 9        100.019946            0.800456
# 10        99.997151            0.999886
# 11        66.667458            0.799926
# 12        42.856852            0.599937
# 13        25.001336            0.399977
# 14        11.111639            0.199989
# 15         0.000000            0.000000
# ModelMetricsBinomial: gbm
# ** Reported on cross-validation data. **
#
# MSE: 0.00863005798696895
# RMSE: 0.09289810540031992
# LogLoss: 0.02687336443998196
# Mean Per-Class Error: 0.0
# AUC: 1.0
# AUCPR: 1.0
# Gini: 1.0
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.3795857976708344:
#                 normal  pathologic Error            Rate
# 0      normal  35102.0         0.0   0.0   (0.0/35102.0)
# 1  pathologic      0.0      1590.0   0.0    (0.0/1590.0)
# 2       Total  35102.0      1590.0   0.0   (0.0/36692.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.379586      1.000000  353.0
# 1                        max f2   0.379586      1.000000  353.0
# 2                  max f0point5   0.379586      1.000000  353.0
# 3                  max accuracy   0.379586      1.000000  353.0
# 4                 max precision   0.642336      1.000000    0.0
# 5                    max recall   0.379586      1.000000  353.0
# 6               max specificity   0.642336      1.000000    0.0
# 7              max absolute_mcc   0.379586      1.000000  353.0
# 8    max min_per_class_accuracy   0.379586      1.000000  353.0
# 9   max mean_per_class_accuracy   0.379586      1.000000  353.0
# 10                      max tns   0.642336  35102.000000    0.0
# 11                      max fns   0.642336   1588.000000    0.0
# 12                      max fps   0.001097  35102.000000  399.0
# 13                      max tps   0.379586   1590.000000  353.0
# 14                      max tnr   0.642336      1.000000    0.0
# 15                      max fnr   0.642336      0.998742    0.0
# 16                      max fpr   0.001097      1.000000  399.0
# 17                      max tpr   0.379586      1.000000  353.0
# Gains/Lift Table: Avg response rate:  4.33 %, avg score:  2.55 %
#     group  cumulative_data_fraction  lower_threshold       lift  \
# 0       1                  0.010002         0.616723  23.076730
# 1       2                  0.020004         0.585058  23.076730
# 2       3                  0.030007         0.528465  23.076730
# 3       4                  0.040009         0.440935  23.076730
# 4       5                  0.050011         0.002768   7.671283
# 5       6                  0.100022         0.002063   0.000000
# 6       7                  0.150005         0.001794   0.000000
# 7       8                  0.200016         0.001624   0.000000
# 8       9                  0.300011         0.001449   0.000000
# 9      10                  0.400033         0.001331   0.000000
# 10     11                  0.500027         0.001262   0.000000
# 11     12                  0.599995         0.001199   0.000000
# 12     13                  0.700016         0.001160   0.000000
# 13     14                  0.799984         0.001136   0.000000
# 14     15                  0.899978         0.001115   0.000000
# 15     16                  1.000000         0.001056   0.000000
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0         23.076730       1.000000  0.625285                  1.000000
# 1         23.076730       1.000000  0.604951                  1.000000
# 2         23.076730       1.000000  0.559507                  1.000000
# 3         23.076730       1.000000  0.492306                  1.000000
# 4         19.995640       0.332425  0.140246                  0.866485
# 5          9.997820       0.000000  0.002362                  0.433243
# 6          6.666424       0.000000  0.001905                  0.288881
# 7          4.999591       0.000000  0.001702                  0.216651
# 8          3.333212       0.000000  0.001533                  0.144440
# 9          2.499796       0.000000  0.001382                  0.108325
# 10         1.999891       0.000000  0.001296                  0.086663
# 11         1.666682       0.000000  0.001229                  0.072223
# 12         1.428538       0.000000  0.001177                  0.061904
# 13         1.250026       0.000000  0.001147                  0.054168
# 14         1.111138       0.000000  0.001126                  0.048150
# 15         1.000000       0.000000  0.001101                  0.043334
#
#     cumulative_score  capture_rate  cumulative_capture_rate         gain  \
# 0           0.625285      0.230818                 0.230818  2207.672956
# 1           0.615118      0.230818                 0.461635  2207.672956
# 2           0.596581      0.230818                 0.692453  2207.672956
# 3           0.570512      0.230818                 0.923270  2207.672956
# 4           0.484459      0.076730                 1.000000   667.128340
# 5           0.243410      0.000000                 1.000000  -100.000000
# 6           0.162938      0.000000                 1.000000  -100.000000
# 7           0.122624      0.000000                 1.000000  -100.000000
# 8           0.082264      0.000000                 1.000000  -100.000000
# 9           0.062041      0.000000                 1.000000  -100.000000
# 10          0.049893      0.000000                 1.000000  -100.000000
# 11          0.041785      0.000000                 1.000000  -100.000000
# 12          0.035983      0.000000                 1.000000  -100.000000
# 13          0.031630      0.000000                 1.000000  -100.000000
# 14          0.028240      0.000000                 1.000000  -100.000000
# 15          0.025526      0.000000                 1.000000  -100.000000
#
#     cumulative_gain  kolmogorov_smirnov
# 0       2207.672956            0.230818
# 1       2207.672956            0.461635
# 2       2207.672956            0.692453
# 3       2207.672956            0.923270
# 4       1899.564033            0.993020
# 5        899.782016            0.940744
# 6        566.642442            0.888496
# 7        399.959122            0.836220
# 8        233.321221            0.731696
# 9        149.979561            0.627144
# 10        99.989099            0.522620
# 11        66.668181            0.418124
# 12        42.853806            0.313572
# 13        25.002555            0.209076
# 14        11.113803            0.104552
# 15         0.000000            0.000000
# Cross-Validation Metrics Summary:
#                                   mean        sd  cv_1_valid  cv_2_valid  \
# 0                  accuracy   1.000000  0.000000    1.000000    1.000000
# 1                       auc   1.000000  0.000000    1.000000    1.000000
# 2                       err   0.000000  0.000000    0.000000    0.000000
# 3                 err_count   0.000000  0.000000    0.000000    0.000000
# 4                  f0point5   1.000000  0.000000    1.000000    1.000000
# 5                        f1   1.000000  0.000000    1.000000    1.000000
# 6                        f2   1.000000  0.000000    1.000000    1.000000
# 7            lift_top_group  23.146027  1.417023   21.521994   23.983660
# 8                   logloss   0.026873  0.001920    0.029098    0.025438
# 9       max_per_class_error   0.000000  0.000000    0.000000    0.000000
# 10                      mcc   1.000000  0.000000    1.000000    1.000000
# 11  mean_per_class_accuracy   1.000000  0.000000    1.000000    1.000000
# 12     mean_per_class_error   0.000000  0.000000    0.000000    0.000000
# 13                      mse   0.008630  0.000720    0.009456    0.008064
# 14                   pr_auc   1.000000  0.000000    1.000000    1.000000
# 15                precision   1.000000  0.000000    1.000000    1.000000
# 16                       r2   0.792031  0.005880    0.786566    0.798174
# 17                   recall   1.000000  0.000000    1.000000    1.000000
# 18                     rmse   0.092833  0.003888    0.097243    0.089801
# 19              specificity   1.000000  0.000000    1.000000    1.000000
#
#     cv_3_valid  cv_4_valid  cv_5_valid
# 0     1.000000    1.000000    1.000000
# 1     1.000000    1.000000    1.000000
# 2     0.000000    0.000000    0.000000
# 3     0.000000    0.000000    0.000000
# 4     1.000000    1.000000    1.000000
# 5     1.000000    1.000000    1.000000
# 6     1.000000    1.000000    1.000000
# 7    24.959183   23.295238   21.970060
# 8     0.024510    0.026983    0.028338
# 9     0.000000    0.000000    0.000000
# 10    1.000000    1.000000    1.000000
# 11    1.000000    1.000000    1.000000
# 12    0.000000    0.000000    0.000000
# 13    0.007746    0.008726    0.009158
# 14    1.000000    1.000000    1.000000
# 15    1.000000    1.000000    1.000000
# 16    0.798603    0.787620    0.789193
# 17    1.000000    1.000000    1.000000
# 18    0.088010    0.093411    0.095700
# 19    1.000000    1.000000    1.000000
# Scoring History:
#                timestamp    duration  number_of_trees  training_rmse  \
# 0    2022-07-10 10:52:45  26.980 sec              0.0       0.677125
# 1    2022-07-10 10:52:45  27.480 sec              5.0       0.639018
# 2    2022-07-10 10:52:46  27.867 sec             10.0       0.589757
# 3    2022-07-10 10:52:47  29.001 sec             15.0       0.520216
# 4    2022-07-10 10:52:48  30.204 sec             20.0       0.442422
# 5    2022-07-10 10:52:49  31.423 sec             25.0       0.357725
# 6    2022-07-10 10:52:51  32.705 sec             30.0       0.281960
#
#    training_logloss  training_auc  training_pr_auc  training_lift  \
# 0          1.591408           0.5          0.49995       1.000000
# 1          1.178800           1.0          1.00000       2.000199
# 2          0.903273           1.0          1.00000       2.000199
# 3          0.668290           1.0          1.00000       2.000199
# 4          0.493191           1.0          1.00000       2.000199
# 5          0.353587           1.0          1.00000       2.000199
# 6          0.254787           1.0          1.00000       2.000199
#
#    training_classification_error
# 0                        0.50005
# 1                        0.00000
# 2                        0.00000
# 3                        0.00000
# 4                        0.00000
# 5                        0.00000
# 6                        0.00000
# Variable Importances:
#                       variable  relative_importance  scaled_importance  \
# 0                onset_channel         89805.976562           1.000000
# 1                ren_20.0-45.0          1174.884766           0.013082
# 2               ren_80.0-250.0           501.634003           0.005586
# 3               HFO_80.0-250.0           141.901260           0.001580
# 4                hlx_20.0-45.0            76.746590           0.000855
# 5                  hlx_0.0-0.0            66.751213           0.000743
# 6              hlx_250.0-600.0            57.209949           0.000637
# 7                hlx_12.0-20.0            49.380680           0.000550
# 8                          fac            46.579731           0.000519
# 9                 hlx_8.0-12.0            45.408897           0.000506
# 10                 hlx_1.0-4.0            44.814693           0.000499
# 11              hlx_80.0-250.0            44.655823           0.000497
# 12         coherence_20.0-45.0            42.838280           0.000477
# 13   lin_corr_median_65.0-80.0            37.489944           0.000417
# 14                         pac            34.920940           0.000389
# 15                 ren_0.0-0.0            34.004097           0.000379
# 16                 ren_1.0-4.0            33.706341           0.000375
# 17  lin_corr_median_80.0-250.0            31.766729           0.000354
# 18   lin_corr_median_20.0-45.0            31.150461           0.000347
# 19                 hlx_4.0-8.0            30.474703           0.000339
#
#     percentage
# 0     0.967548
# 1     0.012658
# 2     0.005404
# 3     0.001529
# 4     0.000827
# 5     0.000719
# 6     0.000616
# 7     0.000532
# 8     0.000502
# 9     0.000489
# 10    0.000483
# 11    0.000481
# 12    0.000462
# 13    0.000404
# 14    0.000376
# 15    0.000366
# 16    0.000363
# 17    0.000342
# 18    0.000336
# 19    0.000328
# See the whole table with table.as_data_frame()

# %%
# H2o AutoML leaderboard 

lb = aml.leaderboard
lb.head(rows=lb.nrows)
# Out:
# <table>
# <thead>
# <tr><th>model_id                                               </th><th style="text-align: right;">     auc</th><th style="text-align: right;">    logloss</th><th style="text-align: right;">   aucpr</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">       rmse</th><th style="text-align: right;">        mse</th></tr>
# </thead>
# <tbody>
# <tr><td>GBM_4_AutoML_2_20220710_104910                         </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0268734  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.0928981  </td><td style="text-align: right;">0.00863006 </td></tr>
# <tr><td>GBM_grid_1_AutoML_2_20220710_104910_model_5            </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0548769  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.141839   </td><td style="text-align: right;">0.0201182  </td></tr>
# <tr><td>GBM_3_AutoML_2_20220710_104910                         </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0346979  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.110231   </td><td style="text-align: right;">0.0121509  </td></tr>
# <tr><td>GBM_grid_1_AutoML_2_20220710_104910_model_2            </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0498993  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.135111   </td><td style="text-align: right;">0.018255   </td></tr>
# <tr><td>GBM_grid_1_AutoML_2_20220710_104910_model_6            </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0199013  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.0733869  </td><td style="text-align: right;">0.00538564 </td></tr>
# <tr><td>DRF_1_AutoML_2_20220710_104910                         </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0428155  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.127828   </td><td style="text-align: right;">0.0163401  </td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_4_AutoML_2_20220710_104910</td><td style="text-align: right;">1       </td><td style="text-align: right;">0.000207506</td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.0014434  </td><td style="text-align: right;">2.08341e-06</td></tr>
# <tr><td>GBM_grid_1_AutoML_2_20220710_104910_model_7            </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0292614  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.0989973  </td><td style="text-align: right;">0.00980048 </td></tr>
# <tr><td>GBM_2_AutoML_2_20220710_104910                         </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0284771  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.0964441  </td><td style="text-align: right;">0.00930146 </td></tr>
# <tr><td>GBM_5_AutoML_2_20220710_104910                         </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0345464  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.109615   </td><td style="text-align: right;">0.0120155  </td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_1_AutoML_2_20220710_104910</td><td style="text-align: right;">1       </td><td style="text-align: right;">0.000206164</td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.000579302</td><td style="text-align: right;">3.3559e-07 </td></tr>
# <tr><td>GBM_grid_1_AutoML_2_20220710_104910_model_4            </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0199067  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.0734048  </td><td style="text-align: right;">0.00538827 </td></tr>
# <tr><td>StackedEnsemble_AllModels_1_AutoML_2_20220710_104910   </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.000196581</td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.000576515</td><td style="text-align: right;">3.32369e-07</td></tr>
# <tr><td>GLM_1_AutoML_2_20220710_104910                         </td><td style="text-align: right;">1       </td><td style="text-align: right;">9.6247e-05 </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.000279791</td><td style="text-align: right;">7.82832e-08</td></tr>
# <tr><td>GBM_grid_1_AutoML_2_20220710_104910_model_3            </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0483056  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.131765   </td><td style="text-align: right;">0.0173621  </td></tr>
# <tr><td>GBM_1_AutoML_2_20220710_104910                         </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0323818  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.105759   </td><td style="text-align: right;">0.011185   </td></tr>
# <tr><td>GBM_grid_1_AutoML_2_20220710_104910_model_9            </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.035875   </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.112001   </td><td style="text-align: right;">0.0125443  </td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_2_AutoML_2_20220710_104910</td><td style="text-align: right;">1       </td><td style="text-align: right;">0.000196613</td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.000576417</td><td style="text-align: right;">3.32256e-07</td></tr>
# <tr><td>GBM_grid_1_AutoML_2_20220710_104910_model_8            </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.0295787  </td><td style="text-align: right;">1       </td><td style="text-align: right;">           0          </td><td style="text-align: right;">0.0988029  </td><td style="text-align: right;">0.00976201 </td></tr>
# <tr><td>StackedEnsemble_AllModels_2_AutoML_2_20220710_104910   </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.000306084</td><td style="text-align: right;">1       </td><td style="text-align: right;">           1.42442e-05</td><td style="text-align: right;">0.0055065  </td><td style="text-align: right;">3.03215e-05</td></tr>
# <tr><td>DeepLearning_grid_2_AutoML_2_20220710_104910_model_1   </td><td style="text-align: right;">1       </td><td style="text-align: right;">0.000164785</td><td style="text-align: right;">1       </td><td style="text-align: right;">           1.42442e-05</td><td style="text-align: right;">0.00649086 </td><td style="text-align: right;">4.21313e-05</td></tr>
# <tr><td>StackedEnsemble_B

# %%
# Explain a single H2O model (e.g. leader model from AutoML)

exm = aml.leader.explain(test)
# Out:
# # Confusion Matrix
# > Confusion matrix shows a predicted class vs an actual class.
# ## GBM_4_AutoML_2_20220710_104910
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.3818924677145917:
#                 normal  pathologic Error            Rate
# 0      normal  11682.0         0.0   0.0   (0.0/11682.0)
# 1  pathologic      0.0       522.0   0.0     (0.0/522.0)
# 2       Total  11682.0       522.0   0.0   (0.0/12204.0)
# # Variable Importance
# > The variable importance plot shows the relative importance of the most important variables in the model.
# # SHAP Summary
# > SHAP summary plot shows the contribution of the features for each instance (row of data). The sum of the feature contributions and the bias term is equal to the raw prediction of the model, i.e., prediction before applying inverse link function.
# # Partial Dependence Plots
# > Partial dependence plot (PDP) gives a graphical depiction of the marginal effect of a variable on the response. The effect of a variable is measured in change in the mean response. PDP assumes independence between the feature for which is the PDP computed and the rest.

# %%
# Leader Gradient Boosting Machine(GBM) model 

model = h2o.get_model('GBM_4_AutoML_2_20220710_104910')

# %%
# Use GBM model on test set

model.model_performance(test)
# Out:
# ModelMetricsBinomial: gbm
# ** Reported on test data. **
#
# MSE: 0.00846633097689477
# RMSE: 0.09201266748059622
# LogLoss: 0.026452368490113728
# Mean Per-Class Error: 0.0
# AUC: 1.0
# AUCPR: 1.0
# Gini: 1.0
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.3818924677145917:
#                 normal  pathologic Error            Rate
# 0      normal  11682.0         0.0   0.0   (0.0/11682.0)
# 1  pathologic      0.0       522.0   0.0     (0.0/522.0)
# 2       Total  11682.0       522.0   0.0   (0.0/12204.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.381892      1.000000  321.0
# 1                        max f2   0.381892      1.000000  321.0
# 2                  max f0point5   0.381892      1.000000  321.0
# 3                  max accuracy   0.381892      1.000000  321.0
# 4                 max precision   0.638340      1.000000    0.0
# 5                    max recall   0.381892      1.000000  321.0
# 6               max specificity   0.638340      1.000000    0.0
# 7              max absolute_mcc   0.381892      1.000000  321.0
# 8    max min_per_class_accuracy   0.381892      1.000000  321.0
# 9   max mean_per_class_accuracy   0.381892      1.000000  321.0
# 10                      max tns   0.638340  11682.000000    0.0
# 11                      max fns   0.638340    521.000000    0.0
# 12                      max fps   0.001095  11682.000000  399.0
# 13                      max tps   0.381892    522.000000  321.0
# 14                      max tnr   0.638340      1.000000    0.0
# 15                      max fnr   0.638340      0.998084    0.0
# 16                      max fpr   0.001095      1.000000  399.0
# 17                      max tpr   0.381892      1.000000  321.0
# Gains/Lift Table: Avg response rate:  4.28 %, avg score:  2.53 %
#     group  cumulative_data_fraction  lower_threshold       lift  \
# 0       1                  0.010079         0.617665  23.379310
# 1       2                  0.020075         0.581565  23.379310
# 2       3                  0.030072         0.530867  23.379310
# 3       4                  0.040069         0.433684  23.379310
# 4       5                  0.050066         0.002767   6.323912
# 5       6                  0.100049         0.002092   0.000000
# 6       7                  0.150033         0.001819   0.000000
# 7       8                  0.200016         0.001642   0.000000
# 8       9                  0.300066         0.001472   0.000000
# 9      10                  0.400033         0.001348   0.000000
# 10     11                  0.500000         0.001280   0.000000
# 11     12                  0.599967         0.001218   0.000000
# 12     13                  0.700016         0.001168   0.000000
# 13     14                  0.799984         0.001138   0.000000
# 14     15                  0.899951         0.001115   0.000000
# 15     16                  1.000000         0.001080   0.000000
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0         23.379310       1.000000  0.623765                  1.000000
# 1         23.379310       1.000000  0.606312                  1.000000
# 2         23.379310       1.000000  0.557797                  1.000000
# 3         23.379310       1.000000  0.489858                  1.000000
# 4         19.973813       0.270492  0.114805                  0.854337
# 5          9.995086       0.000000  0.002388                  0.427518
# 6          6.665210       0.000000  0.001927                  0.285090
# 7          4.999590       0.000000  0.001727                  0.213847
# 8          3.332605       0.000000  0.001549                  0.142545
# 9          2.499795       0.000000  0.001405                  0.106923
# 10         2.000000       0.000000  0.001313                  0.085546
# 11         1.666758       0.000000  0.001250                  0.071292
# 12         1.428538       0.000000  0.001191                  0.061103
# 13         1.250026       0.000000  0.001152                  0.053467
# 14         1.111172       0.000000  0.001127                  0.047528
# 15         1.000000       0.000000  0.001109                  0.042773
#
#     cumulative_score  capture_rate  cumulative_capture_rate         gain  \
# 0           0.623765      0.235632                 0.235632  2237.931034
# 1           0.615074      0.233716                 0.469349  2237.931034
# 2           0.596034      0.233716                 0.703065  2237.931034
# 3           0.569544      0.233716                 0.936782  2237.931034
# 4           0.478745      0.063218                 1.000000   532.391181
# 5           0.240762      0.000000                 1.000000  -100.000000
# 6           0.161194      0.000000                 1.000000  -100.000000
# 7           0.121343      0.000000                 1.000000  -100.000000
# 8           0.081401      0.000000                 1.000000  -100.000000
# 9           0.061410      0.000000                 1.000000  -100.000000
# 10          0.049394      0.000000                 1.000000  -100.000000
# 11          0.041373      0.000000                 1.000000  -100.000000
# 12          0.035630      0.000000                 1.000000  -100.000000
# 13          0.031321      0.000000                 1.000000  -100.000000
# 14          0.027967      0.000000                 1.000000  -100.000000
# 15          0.025280      0.000000                 1.000000  -100.000000
#
#     cumulative_gain  kolmogorov_smirnov
# 0       2237.931034            0.235632
# 1       2237.931034            0.469349
# 2       2237.931034            0.703065
# 3       2237.931034            0.936782
# 4       1897.381342            0.992381
# 5        899.508600            0.940164
# 6        566.521027            0.887947
# 7        399.959033            0.835730
# 8        233.260513            0.731210
# 9        149.979517            0.626776
# 10       100.000000            0.522342
# 11        66.675772            0.417908
# 12        42.853798            0.313388
# 13        25.002561            0.208954
# 14        11.117181            0.104520
# 15         0.000000            0.000000

# %%
# Show variable importance

model.varimp_plot(num_of_features=20)

# %%
# Learning curve plot 

learning_curve_plot = model.learning_curve_plot()

# %%
# Make prediction

preds = aml.leader.predict(test)
# Out:
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%

# %%
# Combine the prediction with the test dataset

df = test.cbind(preds)

# Preview
df.head(10)
# Out:
# <table>
# <thead>
# <tr><th>onset_channel  </th><th>pathology  </th><th style="text-align: right;">  HFO_80.0-250.0</th><th style="text-align: right;">  HFO_250.0-600.0</th><th style="text-align: right;">  spike_rate</th><th style="text-align: right;">  power_1.0-4.0</th><th style="text-align: right;">  power_4.0-8.0</th><th style="text-align: right;">  power_8.0-12.0</th><th style="text-align: right;">  power_12.0-20.0</th><th style="text-align: right;">  power_20.0-45.0</th><th style="text-align: right;">  power_65.0-80.0</th><th style="text-align: right;">  power_80.0-250.0</th><th style="text-align: right;">  power_250.0-600.0</th><th style="text-align: right;">  hlx_0.0-0.0</th><th style="text-align: right;">  hlx_1.0-4.0</th><th style="text-align: right;">  hlx_4.0-8.0</th><th style="text-align: right;">  hlx_8.0-12.0</th><th style="text-align: right;">  hlx_12.0-20.0</th><th style="text-align: right;">  hlx_20.0-45.0</th><th style="text-align: right;">  hlx_65.0-80.0</th><th style="text-align: right;">  hlx_80.0-250.0</th><th style="text-align: right;">  hlx_250.0-600.0</th><th style="text-align: right;">     pse</th><th style="text-align: right;">         pac</th><th style="text-align: right;">         fac</th><th style="text-align: right;">       lfr</th><th style="text-align: right;">  lin_corr_median_0.0-0.0</th><th style="text-align: right;">  ren_0.0-0.0</th><th style="text-align: right;">  phase_sync_0.0-0.0</th><th style="text-align: right;">  phase_const_0.0-0.0</th><th style="text-align: right;">  pli_0.0-0.0</th><th style="text-align: right;">  pli_tau_0.0-0.0</th><th style="text-align: right;">  coherence_0.0-0.0</th><th style="text-align: right;">  lin_corr_median_1.0-4.0</th><th style="text-align: right;">  ren_1.0-4.0</th><th style="text-align: right;">  phase_sync_1.0-4.0</th><th style="text-align: right;">  phase_const_1.0-4.0</th><th style="text-align: right;">  pli_1.0-4.0</th><th style="text-align: right;">  pli_tau_1.0-4.0</th><th style="text-align: right;">  coherence_1.0-4.0</th><th style="text-align: right;">  lin_corr_median_4.0-8.0</th><th style="text-align: right;">  ren_4.0-8.0</th><th style="text-align: right;">  phase_sync_4.0-8.0</th><th style="text-align: right;">  phase_const_4.0-8.0</th><th style="text-align: right;">  pli_4.0-8.0</th><th style="text-align: right;">  pli_tau_4.0-8.0</th><th style="text-align: right;">  coherence_4.0-8.0</th><th style="text-align: right;">  lin_corr_median_8.0-12.0</th><th style="text-align: right;">  ren_8.0-12.0</th><th style="text-align: right;">  phase_sync_8.0-12.0</th><th style="text-align: right;">  phase_const_8.0-12.0</th><th style="text-align: right;">  pli_8.0-12.0</th><th style="text-align: right;">  pli_tau_8.0-12.0</th><th style="text-align: right;">  coherence_8.0-12.0</th><th style="text-align: right;">  lin_corr_median_12.0-20.0</th><th style="text-align: right;">  ren_12.0-20.0</th><th style="text-align: right;">  phase_sync_12.0-20.0</th><th style="text-align: right;">  phase_const_12.0-20.0</th><th style="text-align: right;">  pli_12.0-20.0</th><th style="text-align: right;">  pli_tau_12.0-20.0</th><th style="text-align: right;">  coherence_12.0-20.0</th><th style="text-align: right;">  lin_corr_median_20.0-45.0</th><th style="text-align: right;">  ren_20.0-45.0</th><th style="text-align: right;">  phase_sync_20.0-45.0</th><th style="text-align: right;">  phase_const_20.0-45.0</th><th style="text-align: right;">  pli_20.0-45.0</th><th style="text-align: right;">  pli_tau_20.0-45.0</th><th style="text-align: right;">  coherence_20.0-45.0</th><th style="text-align: right;">  lin_corr_median_65.0-80.0</th><th style="text-align: right;">  ren_65.0-80.0</th><th style="text-align: right;">  phase_sync_65.0-80.0</th><th style="text-align: right;">  phase_const_65.0-80.0</th><th style="text-align: right;">  pli_65.0-80.0</th><th style="text-align: right;">  pli_tau_65.0-80.0</th><th style="text-align: right;">  coherence_65.0-80.0</th><th style="text-align: righ ...
# </thead>
# <tbody>
# <tr><td>NON_SOZ        </td><td>normal     </td><td style="text-align: right;">              17</td><td style="text-align: right;">                2</td><td style="text-align: right;">           4</td><td style="text-align: right;">      0.0854621</td><td style="text-align: right;">     0.0293898 </td><td style="text-align: right;">      0.0131957 </td><td style="text-align: right;">       0.0165244 </td><td style="text-align: right;">       0.0089778 </td><td style="text-align: right;">      0.000294997</td><td style="text-align: right;">       0.000419164</td><td style="text-align: right;">        8.90297e-05</td><td style="text-align: right;">      28.3684</td><td style="text-align: right;">      1.32971</td><td style="text-align: right;">      1.06854</td><td style="text-align: right;">       1.02594</td><td style="text-align: right;">        1.03452</td><td style="text-align: right;">        1.09339</td><td style="text-align: right;">        1.00628</td><td style="text-align: right;">         1.21858</td><td style="text-align: right;">          1.1003 </td><td style="text-align: right;">0.274517</td><td style="text-align: right;"> 0.00376994 </td><td style="text-align: right;">-0.00565821 </td><td style="text-align: right;">0.106004  </td><td style="text-align: right;">              nan        </td><td style="text-align: right;">  nan        </td><td style="text-align: right;">          nan       </td><td style="text-align: right;">                  nan</td><td style="text-align: right;">          nan</td><td style="text-align: right;">              nan</td><td style="text-align: right;">         nan       </td><td style="text-align: right;">              nan        </td><td style="text-align: right;">   nan       </td><td style="text-align: right;">          nan       </td><td style="text-align: right;">                  nan</td><td style="text-align: right;">          nan</td><td style="text-align: right;">              nan</td><td style="text-align: right;">         nan       </td><td style="text-align: right;">              nan        </td><td style="text-align: right;">  nan        </td><td style="text-align: right;">          nan       </td><td style="text-align: right;">                  nan</td><td style="text-align: right;">          nan</td><td style="text-align: right;">              nan</td><td style="text-align: right;">         nan       </td><td style="text-align: right;">               nan        </td><td style="text-align: right;">   nan        </td><td style="text-align: right;">           nan       </td><td style="text-align: right;">                   nan</td><td style="text-align: right;">           nan</td><td style="text-align: right;">               nan</td><td style="text-align: right;">          nan       </td><td style="text-align: right;">                nan        </td><td style="text-align: right;">    nan        </td><td style="text-align: right;">            nan       </td><td style=

# %%
# Create dataframe for first 20 predictions

df = h2o.as_list(df)

preds = df[['pathology', 'predict']].head(20)
preds
# Out:
#    pathology predict
# 0     normal  normal
# 1     normal  normal
# 2     normal  normal
# 3     normal  normal
# 4     normal  normal
# 5     normal  normal
# 6     normal  normal
# 7     normal  normal
# 8     normal  normal
# 9     normal  normal
# 10    normal  normal
# 11    normal  normal
# 12    normal  normal
# 13    normal  normal
# 14    normal  normal
# 15    normal  normal
# 16    normal  normal
# 17    normal  normal
# 18    normal  normal
# 19    normal  normal

# %%
# Save the results

#df.to_csv('df.csv')
#preds.to_csv('preds.csv')
