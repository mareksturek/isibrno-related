# %%
# Import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)

# %%
# Import dataset

df = pd.read_csv('~/Marek/2_PhD/ISI/Work/data/new_isi_data.csv')
# Remove unnamed column: ,index_col=0
df.head()
# Out:
#    Unnamed: 0  patient_id channel_name  resected onset_channel  outcome  \
# 0           0         583          ra1         0       NON_SOZ     11.0
# 1           1         583          ra2         0       NON_SOZ     11.0
# 2           2         583          ra3         0       NON_SOZ     11.0
# 3           3         583          ra4         0       NON_SOZ     11.0
# 4           4         583          ra5         0       NON_SOZ     11.0
#
#    HFO_80.0-250.0  HFO_250.0-600.0  spike_rate  power_1.0-4.0  ...  \
# 0              11               34          22       0.533375  ...
# 1              16               40          49       0.518898  ...
# 2              20               35          61       0.466505  ...
# 3              27               37          66       0.444008  ...
# 4              11               58          63       0.588096  ...
#
#    lin_corr_median_80.0-250.0  ren_80.0-250.0  phase_sync_80.0-250.0  \
# 0                    0.995615        0.003025               0.985229
# 1                    0.999169        0.000649               0.996365
# 2                    0.999172        0.000648               0.996397
# 3                    0.997592        0.001411               0.991613
# 4                    0.994437        0.003369               0.981503
#
#    coherence_80.0-250.0  lin_corr_median_250.0-600.0  ren_250.0-600.0  \
# 0              0.997413                     0.990955         0.004121
# 1              0.999503                     0.997006         0.001574
# 2              0.999509                     0.996981         0.001719
# 3              0.998744                     0.994820         0.002903
# 4              0.996723                     0.996824         0.001831
#
#    phase_sync_250.0-600.0  coherence_250.0-600.0  segm_type  segm_number
# 0                0.970733               0.994151          0            0
# 1                0.987965               0.997992          0            0
# 2                0.987949               0.997969          0            0
# 3                0.984822               0.997324          0            0
# 4                0.987556               0.997855          0            0
#
# [5 rows x 68 columns]

# %%
# Drop index column

df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
#    patient_id channel_name  resected onset_channel  outcome  HFO_80.0-250.0  \
# 0         583          ra1         0       NON_SOZ     11.0              11
# 1         583          ra2         0       NON_SOZ     11.0              16
# 2         583          ra3         0       NON_SOZ     11.0              20
# 3         583          ra4         0       NON_SOZ     11.0              27
# 4         583          ra5         0       NON_SOZ     11.0              11
#
#    HFO_250.0-600.0  spike_rate  power_1.0-4.0  power_4.0-8.0  ...  \
# 0               34          22       0.533375       0.781969  ...
# 1               40          49       0.518898       0.780688  ...
# 2               35          61       0.466505       0.740345  ...
# 3               37          66       0.444008       0.721173  ...
# 4               58          63       0.588096       0.937518  ...
#
#    lin_corr_median_80.0-250.0  ren_80.0-250.0  phase_sync_80.0-250.0  \
# 0                    0.995615        0.003025               0.985229
# 1                    0.999169        0.000649               0.996365
# 2                    0.999172        0.000648               0.996397
# 3                    0.997592        0.001411               0.991613
# 4                    0.994437        0.003369               0.981503
#
#    coherence_80.0-250.0  lin_corr_median_250.0-600.0  ren_250.0-600.0  \
# 0              0.997413                     0.990955         0.004121
# 1              0.999503                     0.997006         0.001574
# 2              0.999509                     0.996981         0.001719
# 3              0.998744                     0.994820         0.002903
# 4              0.996723                     0.996824         0.001831
#
#    phase_sync_250.0-600.0  coherence_250.0-600.0  segm_type  segm_number
# 0                0.970733               0.994151          0            0
# 1                0.987965               0.997992          0            0
# 2                0.987949               0.997969          0            0
# 3                0.984822               0.997324          0            0
# 4                0.987556               0.997855          0            0
#
# [5 rows x 67 columns]

# %%
# Drop "nan" channels across all segments

df_nans = df[df.isnull().any(axis=1)]
for pts in df_nans.patient_id.unique():
    for chns in list(df_nans.loc[df_nans.patient_id == pts,'channel_name'].unique()):
        df = df.drop(df[(df.patient_id == pts) & (df.channel_name == chns)].index)

# %%
# Dataframe preparation, target column 

outcome_11 = 11

df = df[df.outcome <= outcome_11]
mask = df.onset_channel == 'NON_SOZ'
df.loc[mask, 'onset_channel'] = 0
mask = df.onset_channel == 'SOZ'
df.loc[mask, 'onset_channel'] = 1
tmp = df['resected'].values * df['onset_channel'].values
df['target'] = tmp.astype(int)
df = df.rename(columns={'spike_rate':'spike_rate_0.0-0.0',
                        'pse':'pse_0.0-0.0',
                        'pac':'pac_0.0-0.0',
                        'fac':'fac_0.0-0.0',
                        'lfr':'lfr_0.0-0.0'})

features = [x for x in df if any(c.isdigit() for c in x)]
features.sort()

# %%
# Drop no target pts

target = 'target'
for pts in df.patient_id.unique():
    if sum(df.loc[df.patient_id == pts,target]) == 0:
        #print('patient',str(pts),'does not have target - droping this patient')
        df = df[df.patient_id != pts]

# %%
# Keep only segm_type = 4 

df = df.loc[df['segm_type'] == 4]
print(df.shape)
df.head()
# Out:
# (1959, 68)
#        patient_id channel_name  resected onset_channel  outcome  \
# 34674         583          ra1         0             0     11.0
# 34675         583          ra2         0             0     11.0
# 34676         583          ra3         0             0     11.0
# 34677         583          ra4         0             0     11.0
# 34678         583          ra5         0             0     11.0
#
#        HFO_80.0-250.0  HFO_250.0-600.0  spike_rate_0.0-0.0  power_1.0-4.0  \
# 34674              19               56                  50       0.526201
# 34675              35               62                  86       0.560877
# 34676              36               66                 101       0.558763
# 34677              47               66                 102       0.554024
# 34678              32               75                  96       0.649021
#
#        power_4.0-8.0  ...  ren_80.0-250.0  phase_sync_80.0-250.0  \
# 34674       0.474988  ...        0.008171               0.962278
# 34675       0.560381  ...        0.001929               0.989986
# 34676       0.576171  ...        0.002038               0.989737
# 34677       0.565439  ...        0.005044               0.975965
# 34678       0.658895  ...        0.009224               0.944790
#
#        coherence_80.0-250.0  lin_corr_median_250.0-600.0  ren_250.0-600.0  \
# 34674              0.992315                     0.951701         0.015386
# 34675              0.998410                     0.982513         0.007849
# 34676              0.998386                     0.982065         0.007308
# 34677              0.995656                     0.975849         0.009962
# 34678              0.987954                     0.980963         0.007094
#
#        phase_sync_250.0-600.0  coherence_250.0-600.0  segm_type  segm_number  \
# 34674                0.894617               0.968141          4            0
# 34675                0.952962               0.988048          4            0
# 34676                0.951814               0.987657          4            0
# 34677                0.941062               0.984107          4            0
# 34678                0.949647               0.986945          4            0
#
#        target
# 34674       0
# 34675       0
# 34676       0
# 34677       0
# 34678       0
#
# [5 rows x 68 columns]

# %%
# Number of unique patients

print(len(df.patient_id.unique()))
patients = df.patient_id.unique()
patients = np.sort(patients)
patients
# Out:
# 18
# array([  61,   63,   71,   77,   82,   89,   93,  583,  657,  717,  723,
#         953,  965, 1002, 1021, 1041, 1043, 1630])

# %%
# Scale selected features with standard scaler (z-score)

from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder        
scaler = StandardScaler()
for pts in df.patient_id.unique(): 
    df.loc[df.patient_id == pts,features] = scaler.fit_transform(df.loc[df.patient_id == pts,features])

# %%
# Create a list of the columns
columns_to_keep = ['patient_id'] + [col for col in df.columns[5:65]] + ['target']

# A new DataFrame with only those columns
lazy_df = df[columns_to_keep]

# %%
# View lazy_df

lazy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1959 entries, 34674 to 40452
# Data columns (total 62 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   patient_id                   1959 non-null   int64
#  1   HFO_80.0-250.0               1959 non-null   float64
#  2   HFO_250.0-600.0              1959 non-null   float64
#  3   spike_rate_0.0-0.0           1959 non-null   float64
#  4   power_1.0-4.0                1959 non-null   float64
#  5   power_4.0-8.0                1959 non-null   float64
#  6   power_8.0-12.0               1959 non-null   float64
#  7   power_12.0-20.0              1959 non-null   float64
#  8   power_20.0-45.0              1959 non-null   float64
#  9   power_65.0-80.0              1959 non-null   float64
#  10  power_80.0-250.0             1959 non-null   float64
#  11  power_250.0-600.0            1959 non-null   float64
#  12  hlx_0.0-0.0                  1959 non-null   float64
#  13  hlx_1.0-4.0                  1959 non-null   float64
#  14  hlx_4.0-8.0                  1959 non-null   float64
#  15  hlx_8.0-12.0                 1959 non-null   float64
#  16  hlx_12.0-20.0                1959 non-null   float64
#  17  hlx_20.0-45.0                1959 non-null   float64
#  18  hlx_65.0-80.0                1959 non-null   float64
#  19  hlx_80.0-250.0               1959 non-null   float64
#  20  hlx_250.0-600.0              1959 non-null   float64
#  21  pse_0.0-0.0                  1959 non-null   float64
#  22  pac_0.0-0.0                  1959 non-null   float64
#  23  fac_0.0-0.0                  1959 non-null   float64
#  24  lfr_0.0-0.0                  1959 non-null   float64
#  25  lin_corr_median_0.0-0.0      1959 non-null   float64
#  26  ren_0.0-0.0                  1959 non-null   float64
#  27  phase_sync_0.0-0.0           1959 non-null   float64
#  28  coherence_0.0-0.0            1959 non-null   float64
#  29  lin_corr_median_1.0-4.0      1959 non-null   float64
#  30  ren_1.0-4.0                  1959 non-null   float64
#  31  phase_sync_1.0-4.0           1959 non-null   float64
#  32  coherence_1.0-4.0            1959 non-null   float64
#  33  lin_corr_median_4.0-8.0      1959 non-null   float64
#  34  ren_4.0-8.0                  1959 non-null   float64
#  35  phase_sync_4.0-8.0           1959 non-null   float64
#  36  coherence_4.0-8.0            1959 non-null   float64
#  37  lin_corr_median_8.0-12.0     1959 non-null   float64
#  38  ren_8.0-12.0                 1959 non-null   float64
#  39  phase_sync_8.0-12.0          1959 non-null   float64
#  40  coherence_8.0-12.0           1959 non-null   float64
#  41  lin_corr_median_12.0-20.0    1959 non-null   float64
#  42  ren_12.0-20.0                1959 non-null   float64
#  43  phase_sync_12.0-20.0         1959 non-null   float64
#  44  coherence_12.0-20.0          1959 non-null   float64
#  45  lin_corr_median_20.0-45.0    1959 non-null   float64
#  46  ren_20.0-45.0                1959 non-null   float64
#  47  phase_sync_20.0-45.0         1959 non-null   float64
#  48  coherence_20.0-45.0          1959 non-null   float64
#  49  lin_corr_median_65.0-80.0    1959 non-null   float64
#  50  ren_65.0-80.0                1959 non-null   float64
#  51  phase_sync_65.0-80.0         1959 non-null   float64
#  52  coherence_65.0-80.0          1959 non-null   float64
#  53  lin_corr_median_80.0-250.0   1959 non-null   float64
#  54  ren_80.0-250.0               1959 non-null   float64
#  55  phase_sync_80.0-250.0        1959 non-null   float64
#  56  coherence_80.0-250.0         1959 non-null   float64
#  57  lin_corr_median_250.0-600.0  1959 non-null   float64
#  58  ren_250.0-600.0              1959 non-null   float64
#  59  phase_sync_250.0-600.0       1959 non-null   float64
#  60  coherence_250.0-600.0        1959 non-null   float64
#  61  target                       1959 non-null   int64
# dtypes: float64(60), int64(2)
# memory usage: 964.2 KB

# %%
# Archive legacy Lazy model 

'''
import pandas as pd
pd.set_option('display.max_colwidth', -1)
from IPython.display import display
from sklearn.model_selection import LeaveOneGroupOut
from lazypredict.Supervised import LazyClassifier
from sklearn.metrics import accuracy_score

# Define the group column
group = 'patient_id'

# Split the data into X and y
X = lazy_df.drop(columns=target)
y = lazy_df[target]

logo = LeaveOneGroupOut()
for train_index, test_index in logo.split(X, y, groups=lazy_df[group]):
    X_train, X_test = X.iloc[train_index].drop(columns=[group]), X.iloc[test_index].drop(columns=[group])
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    selected_patient_id = lazy_df.iloc[test_index][group].unique()
    print("Selected patient ID: ", selected_patient_id)
    clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
    models,predictions = clf.fit(X_train, X_test, y_train, y_test)
'''

# %%
# Revised Lazy model, including display object, a library for handling imbalanced datasets in machine learning

import pandas as pd
pd.set_option('display.max_colwidth', -1)
from IPython.display import display
from sklearn.model_selection import LeaveOneGroupOut
from lazypredict.Supervised import LazyClassifier
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE

# Define the group column
group = 'patient_id'

# Split the data into X and y
X = lazy_df.drop(columns=target)
y = lazy_df[target]

logo = LeaveOneGroupOut()

for train_index, test_index in logo.split(X, y, groups=lazy_df[group]):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    selected_patient_id = lazy_df.iloc[test_index][group].unique()
    print("Selected patient ID: ", selected_patient_id)
    print("X_train shape: ", X_train.shape)
    print("X_test shape: ", X_test.shape)
    print("y_train shape: ", y_train.shape)
    print("y_test shape: ", y_test.shape)
    # oversampling the minority class using SMOTE
    sm = SMOTE(sampling_strategy='auto')
    X_train, y_train = sm.fit_resample(X_train, y_train)
    clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
    models,predictions = clf.fit(X_train.drop(columns=[group]), X_test.drop(columns=[group]), y_train, y_test)
    display(models.style.set_properties(**{'font-size': '9pt'}))
# Out:
# Selected patient ID:  [61]
# X_train shape:  (1809, 61)
# X_test shape:  (150, 61)
# y_train shape:  (1809,)
# y_test shape:  (150,)
# 100%|███████████████████████████████████████████| 29/29 [00:08<00:00,  3.44it/s]
# <style type="text/css">
# #T_f5d6d_row0_col0, #T_f5d6d_row0_col1, #T_f5d6d_row0_col2, #T_f5d6d_row0_col3, #T_f5d6d_row0_col4, #T_f5d6d_row1_col0, #T_f5d6d_row1_col1, #T_f5d6d_row1_col2, #T_f5d6d_row1_col3, #T_f5d6d_row1_col4, #T_f5d6d_row2_col0, #T_f5d6d_row2_col1, #T_f5d6d_row2_col2, #T_f5d6d_row2_col3, #T_f5d6d_row2_col4, #T_f5d6d_row3_col0, #T_f5d6d_row3_col1, #T_f5d6d_row3_col2, #T_f5d6d_row3_col3, #T_f5d6d_row3_col4, #T_f5d6d_row4_col0, #T_f5d6d_row4_col1, #T_f5d6d_row4_col2, #T_f5d6d_row4_col3, #T_f5d6d_row4_col4, #T_f5d6d_row5_col0, #T_f5d6d_row5_col1, #T_f5d6d_row5_col2, #T_f5d6d_row5_col3, #T_f5d6d_row5_col4, #T_f5d6d_row6_col0, #T_f5d6d_row6_col1, #T_f5d6d_row6_col2, #T_f5d6d_row6_col3, #T_f5d6d_row6_col4, #T_f5d6d_row7_col0, #T_f5d6d_row7_col1, #T_f5d6d_row7_col2, #T_f5d6d_row7_col3, #T_f5d6d_row7_col4, #T_f5d6d_row8_col0, #T_f5d6d_row8_col1, #T_f5d6d_row8_col2, #T_f5d6d_row8_col3, #T_f5d6d_row8_col4, #T_f5d6d_row9_col0, #T_f5d6d_row9_col1, #T_f5d6d_row9_col2, #T_f5d6d_row9_col3, #T_f5d6d_row9_col4, #T_f5d6d_row10_col0, #T_f5d6d_row10_col1, #T_f5d6d_row10_col2, #T_f5d6d_row10_col3, #T_f5d6d_row10_col4, #T_f5d6d_row11_col0, #T_f5d6d_row11_col1, #T_f5d6d_row11_col2, #T_f5d6d_row11_col3, #T_f5d6d_row11_col4, #T_f5d6d_row12_col0, #T_f5d6d_row12_col1, #T_f5d6d_row12_col2, #T_f5d6d_row12_col3, #T_f5d6d_row12_col4, #T_f5d6d_row13_col0, #T_f5d6d_row13_col1, #T_f5d6d_row13_col2, #T_f5d6d_row13_col3, #T_f5d6d_row13_col4, #T_f5d6d_row14_col0, #T_f5d6d_row14_col1, #T_f5d6d_row14_col2, #T_f5d6d_row14_col3, #T_f5d6d_row14_col4, #T_f5d6d_row15_col0, #T_f5d6d_row15_col1, #T_f5d6d_row15_col2, #T_f5d6d_row15_col3, #T_f5d6d_row15_col4, #T_f5d6d_row16_col0, #T_f5d6d_row16_col1, #T_f5d6d_row16_col2, #T_f5d6d_row16_col3, #T_f5d6d_row16_col4, #T_f5d6d_row17_col0, #T_f5d6d_row17_col1, #T_f5d6d_row17_col2, #T_f5d6d_row17_col3, #T_f5d6d_row17_col4, #T_f5d6d_row18_col0, #T_f5d6d_row18_col1, #T_f5d6d_row18_col2, #T_f5d6d_row18_col3, #T_f5d6d_row18_col4, #T_f5d6d_row19_col0, #T_f5d6d_row19_col1, #T_f5d6d_row19_col2, #T_f5d6d_row19_col3, #T_f5d6d_row19_col4, #T_f5d6d_row20_col0, #T_f5d6d_row20_col1, #T_f5d6d_row20_col2, #T_f5d6d_row20_col3, #T_f5d6d_row20_col4, #T_f5d6d_row21_col0, #T_f5d6d_row21_col1, #T_f5d6d_row21_col2, #T_f5d6d_row21_col3, #T_f5d6d_row21_col4, #T_f5d6d_row22_col0, #T_f5d6d_row22_col1, #T_f5d6d_row22_col2, #T_f5d6d_row22_col3, #T_f5d6d_row22_col4, #T_f5d6d_row23_col0, #T_f5d6d_row23_col1, #T_f5d6d_row23_col2, #T_f5d6d_row23_col3, #T_f5d6d_row23_col4, #T_f5d6d_row24_col0, #T_f5d6d_row24_col1, #T_f5d6d_row24_col2, #T_f5d6d_row24_col3, #T_f5d6d_row24_col4, #T_f5d6d_row25_col0, #T_f5d6d_row25_col1, #T_f5d6d_row25_col2, #T_f5d6d_row25_col3, #T_f5d6d_row25_col4, #T_f5d6d_row26_col0, #T_f5d6d_row26_col1, #T_f5d6d_row26_col2, #T_f5d6d_row26_col3, #T_f5d6d_row26_col4 {
#   font-size: 9pt;
# }
# </style>
# <table id="T_f5d6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5d6d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f5d6d_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_f5d6d_level0_col2" class="col_heading level0 col2" >ROC AUC</th>
#       <th id="T_f5d6d_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_f5d6d_level0_col4" class="col_heading level0 col4" >Time Taken</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5d6d_level0_row0" class="row_heading level0 row0" >LinearDiscriminantAnalysis</th>
#       <td id="T_f5d6d_row0_col0" class="data row0 col0" >0.813333</td>
#       <td id="T_f5d6d_row0_col1" class="data row0 col1" >0.848700</td>
#       <td id="T_f5d6d_row0_col2" class="data row0 col2" >0.848700</td>
#       <td id="T_f5d6d_row0_col3" class="data row0 col3" >0.859006</td>
#       <td id="T_f5d6d_row0_col4" class="data row0 col4" >0.060872</td>
#     </tr>
#     <tr>
#       <th id="T_f5d6d_level0_row1" class="row_heading level0 row1" >RidgeClassifier</th>
#       <td id="T_f5d6d_row1_col0" class="data row1 col0" >0.813333</td>
#       <td id="T_f5d6d_row1_col1" class="data row1 col1" >0.848700</td>
#       <td id="T_f5d6d_row1_col2" class="data row1 col2" >0.848700</td>
#       <td id="T_f5d6d_row1_col3" class="data row1 col3" >0.859006</td>
#       <td id="T_f5d6d_row1_col4" class="data row1 col4" >0.028867</td>
#     </tr>
#     <tr>
#       <th id="T_f5d6d_level0_row2" class="row_heading level0 row2" >CalibratedClassifierCV</th>
#       <td id="T_f5d6d_row2_col0" class="data row2 col0" >0.833333</td>
#       <td id="T_f5d6d_row2_col1" class="data row2 col1" >0.807329</td>
#       <td id="T_f5d6d_row2_col2" class="data row2 col2" >0.807329</td>
#       <td id="T_f5d6d_row2_col3" class="data row2 col3" >0.871500</td>
#       <td id="T_f5d6d_row2_col4" class="data row2 col4" >1.357625</td>
#     </tr>
#     <tr>
#       <th id="T_f5d6d_level0_row3" class="row_heading level0 row3" >LinearSVC</th>
#       <td id="T_f5d6d_row3_col0" class="data row3 col0" >0.820000</td>
#       <td id="T_f5d6d_row3_col1" class="data row3 col1" >0.800236</td>
#       <td id="T_f5d6d_row3_col2" class="data row3 col2" >0.800236</td>
#       <td id="T_f5d6d_row3_col3" class="data row3 col3" >0.862496</td>
#       <td id="T_f5d6d_row3_col4" class="data row3 col4" >0.386101</td>
#     </tr>
#     <tr>
#       <th id="T_f5d6d_level0_row4" class="row_heading level0 row4" >BaggingClassifier</th>
#       <td id="T_f5d6d_row4_col0" class="data row4 col0" >0.860000</td>
#       <td id="T_f5d6d_row4_col1" class="data row4 col1" >0.717494</td>
#       <td id="T_f5d6d_row4_col2" class="data row4 col2" >0.717494</td>
#       <td id="T_f5d6d_row4_col3" class="data row4 col3" >0.885972</td>
#       <td id="T_f5d6d_row4_col4" class="data row4 col4" >1.206248</td>
#     </tr>
#     <tr>
#       <th id="T_f5d6d_level0_row5" class="row_heading level0 row5" >NuSVC</th>
#       <td id="T_f5d6d_row5_col0" class="data row5 col0" >0.853333</td>
#       <td id="T_f5d6d_row5_col1" class="data row5 col1" >0.713948</td>
#       <td id="T_f5d6d_row5_col2" class="data row5 col2" >0.713948</td>
#       <td id="T_f5d6d_row5_col3" class="data row5 col3" >0.881586</td>
#       <td id="T_f5d6d_row5_col4" class="data row5 col4" >0.400160</td>
#     </tr>
#     <tr>
#       <th id="T_f5d6d_level0_row6" class="row_heading level0 row6" >NearestCentroid</th>
#       <td id="T_f5d6d_row6_col0" class="data row6 col0" >0.733333</td>
#       <td id="T_f5d6d_row6_col1" class="data row6 col1" >0.702128</td>
#       <td id="T_f5d6d_row6_col2" class="data row6 col2" >0.702128</td>
#       <td id="T_f5d6d_row6_col3" class="data row6 col3" >0.802233</td>
#       <td id="T_f5d6d_row6_col4" class="data row6 col4" >0.013656</td>
#     </tr>
#     <tr>
#       <th id="T_f5d6d_level0_row7" class="row_heading level0 row7" >RandomForestClassifier</th>
#       <td id="T_f5d6d_row7_col0" class="data row7 col0" >0.913333</td>
#       <td id="T_f5d6d_row7_col1" class="data row7 col1" >0.693853</td>
#       <td id="T_f5d6d_row7_col2" class="data row7 col2" >0.693853</td>
#       <td id="T_f5d6d_row7_col3" class="data row7 col3" >0.919058</td>
#       <td id="T_f5d6d_row7_col4" class="data row7 col4" >1.349251</td>
#     </tr>
#     <tr>
#       <th id="T_f5d6d_level0_row8" class="row_heading level0 row8" >LogisticRegression</th>
#       <td id="T_f5d6d_row8_col0" class="data row8 col0" >0.806667</td>
#       <td id="T_f5d6d_row8_col1" class="data row8 col1" >0.689125</td>
#       <td id="T_f5d6d_row8_col2" class="data row8 col2" >0.689125</td>
#       <td id="T_f5d6d_row8_col3" class="data row8 col3" >0.850940</td>
#       <td id="T_f5d6d_row8_col4" class="data row8 col4" >0.055938</td>
#     </tr>
#     <tr>
#       <th id="T_f5d6d_level0_row9" class="row_heading level0 row9" >RidgeClassifierCV</th>
#       <td id="T_f5d6d_row9_col0" class="data row9 col0" >0.800000</t
# Selected patient ID:  [63]
# X_train shape:  (1839, 61)
# X_test shape:  (120, 61)
# y_train shape:  (1839,)
# y_test shape:  (120,)
# 100%|███████████████████████████████████████████| 29/29 [00:08<00:00,  3.35it/s]
# <style type="text/css">
# #T_693e8_row0_col0, #T_693e8_row0_col1, #T_693e8_row0_col2, #T_693e8_row0_col3, #T_693e8_row0_col4, #T_693e8_row1_col0, #T_693e8_row1_col1, #T_693e8_row1_col2, #T_693e8_row1_col3, #T_693e8_row1_col4, #T_693e8_row2_col0, #T_693e8_row2_col1, #T_693e8_row2_col2, #T_693e8_row2_col3, #T_693e8_row2_col4, #T_693e8_row3_col0, #T_693e8_row3_col1, #T_693e8_row3_col2, #T_693e8_row3_col3, #T_693e8_row3_col4, #T_693e8_row4_col0, #T_693e8_row4_col1, #T_693e8_row4_col2, #T_693e8_row4_col3, #T_693e8_row4_col4, #T_693e8_row5_col0, #T_693e8_row5_col1, #T_693e8_row5_col2, #T_693e8_row5_col3, #T_693e8_row5_col4, #T_693e8_row6_col0, #T_693e8_row6_col1, #T_693e8_row6_col2, #T_693e8_row6_col3, #T_693e8_row6_col4, #T_693e8_row7_col0, #T_693e8_row7_col1, #T_693e8_row7_col2, #T_693e8_row7_col3, #T_693e8_row7_col4, #T_693e8_row8_col0, #T_693e8_row8_col1, #T_693e8_row8_col2, #T_693e8_row8_col3, #T_693e8_row8_col4, #T_693e8_row9_col0, #T_693e8_row9_col1, #T_693e8_row9_col2, #T_693e8_row9_col3, #T_693e8_row9_col4, #T_693e8_row10_col0, #T_693e8_row10_col1, #T_693e8_row10_col2, #T_693e8_row10_col3, #T_693e8_row10_col4, #T_693e8_row11_col0, #T_693e8_row11_col1, #T_693e8_row11_col2, #T_693e8_row11_col3, #T_693e8_row11_col4, #T_693e8_row12_col0, #T_693e8_row12_col1, #T_693e8_row12_col2, #T_693e8_row12_col3, #T_693e8_row12_col4, #T_693e8_row13_col0, #T_693e8_row13_col1, #T_693e8_row13_col2, #T_693e8_row13_col3, #T_693e8_row13_col4, #T_693e8_row14_col0, #T_693e8_row14_col1, #T_693e8_row14_col2, #T_693e8_row14_col3, #T_693e8_row14_col4, #T_693e8_row15_col0, #T_693e8_row15_col1, #T_693e8_row15_col2, #T_693e8_row15_col3, #T_693e8_row15_col4, #T_693e8_row16_col0, #T_693e8_row16_col1, #T_693e8_row16_col2, #T_693e8_row16_col3, #T_693e8_row16_col4, #T_693e8_row17_col0, #T_693e8_row17_col1, #T_693e8_row17_col2, #T_693e8_row17_col3, #T_693e8_row17_col4, #T_693e8_row18_col0, #T_693e8_row18_col1, #T_693e8_row18_col2, #T_693e8_row18_col3, #T_693e8_row18_col4, #T_693e8_row19_col0, #T_693e8_row19_col1, #T_693e8_row19_col2, #T_693e8_row19_col3, #T_693e8_row19_col4, #T_693e8_row20_col0, #T_693e8_row20_col1, #T_693e8_row20_col2, #T_693e8_row20_col3, #T_693e8_row20_col4, #T_693e8_row21_col0, #T_693e8_row21_col1, #T_693e8_row21_col2, #T_693e8_row21_col3, #T_693e8_row21_col4, #T_693e8_row22_col0, #T_693e8_row22_col1, #T_693e8_row22_col2, #T_693e8_row22_col3, #T_693e8_row22_col4, #T_693e8_row23_col0, #T_693e8_row23_col1, #T_693e8_row23_col2, #T_693e8_row23_col3, #T_693e8_row23_col4, #T_693e8_row24_col0, #T_693e8_row24_col1, #T_693e8_row24_col2, #T_693e8_row24_col3, #T_693e8_row24_col4, #T_693e8_row25_col0, #T_693e8_row25_col1, #T_693e8_row25_col2, #T_693e8_row25_col3, #T_693e8_row25_col4, #T_693e8_row26_col0, #T_693e8_row26_col1, #T_693e8_row26_col2, #T_693e8_row26_col3, #T_693e8_row26_col4 {
#   font-size: 9pt;
# }
# </style>
# <table id="T_693e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_693e8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_693e8_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_693e8_level0_col2" class="col_heading level0 col2" >ROC AUC</th>
#       <th id="T_693e8_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_693e8_level0_col4" class="col_heading level0 col4" >Time Taken</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_693e8_level0_row0" class="row_heading level0 row0" >CalibratedClassifierCV</th>
#       <td id="T_693e8_row0_col0" class="data row0 col0" >0.816667</td>
#       <td id="T_693e8_row0_col1" class="data row0 col1" >0.905983</td>
#       <td id="T_693e8_row0_col2" class="data row0 col2" >0.905983</td>
#       <td id="T_693e8_row0_col3" class="data row0 col3" >0.879178</td>
#       <td id="T_693e8_row0_col4" class="data row0 col4" >1.379496</td>
#     </tr>
#     <tr>
#       <th id="T_693e8_level0_row1" class="row_heading level0 row1" >LinearSVC</th>
#       <td id="T_693e8_row1_col0" class="data row1 col0" >0.800000</td>
#       <td id="T_693e8_row1_col1" class="data row1 col1" >0.897436</td>
#       <td id="T_693e8_row1_col2" class="data row1 col2" >0.897436</td>
#       <td id="T_693e8_row1_col3" class="data row1 col3" >0.868571</td>
#       <td id="T_693e8_row1_col4" class="data row1 col4" >0.387227</td>
#     </tr>
#     <tr>
#       <th id="T_693e8_level0_row2" class="row_heading level0 row2" >LogisticRegression</th>
#       <td id="T_693e8_row2_col0" class="data row2 col0" >0.783333</td>
#       <td id="T_693e8_row2_col1" class="data row2 col1" >0.888889</td>
#       <td id="T_693e8_row2_col2" class="data row2 col2" >0.888889</td>
#       <td id="T_693e8_row2_col3" class="data row2 col3" >0.857813</td>
#       <td id="T_693e8_row2_col4" class="data row2 col4" >0.044806</td>
#     </tr>
#     <tr>
#       <th id="T_693e8_level0_row3" class="row_heading level0 row3" >LinearDiscriminantAnalysis</th>
#       <td id="T_693e8_row3_col0" class="data row3 col0" >0.775000</td>
#       <td id="T_693e8_row3_col1" class="data row3 col1" >0.884615</td>
#       <td id="T_693e8_row3_col2" class="data row3 col2" >0.884615</td>
#       <td id="T_693e8_row3_col3" class="data row3 col3" >0.852372</td>
#       <td id="T_693e8_row3_col4" class="data row3 col4" >0.037469</td>
#     </tr>
#     <tr>
#       <th id="T_693e8_level0_row4" class="row_heading level0 row4" >PassiveAggressiveClassifier</th>
#       <td id="T_693e8_row4_col0" class="data row4 col0" >0.708333</td>
#       <td id="T_693e8_row4_col1" class="data row4 col1" >0.850427</td>
#       <td id="T_693e8_row4_col2" class="data row4 col2" >0.850427</td>
#       <td id="T_693e8_row4_col3" class="data row4 col3" >0.807176</td>
#       <td id="T_693e8_row4_col4" class="data row4 col4" >0.018286</td>
#     </tr>
#     <tr>
#       <th id="T_693e8_level0_row5" class="row_heading level0 row5" >XGBClassifier</th>
#       <td id="T_693e8_row5_col0" class="data row5 col0" >0.908333</td>
#       <td id="T_693e8_row5_col1" class="data row5 col1" >0.790598</td>
#       <td id="T_693e8_row5_col2" class="data row5 col2" >0.790598</td>
#       <td id="T_693e8_row5_col3" class="data row5 col3" >0.934000</td>
#       <td id="T_693e8_row5_col4" class="data row5 col4" >0.364334</td>
#     </tr>
#     <tr>
#       <th id="T_693e8_level0_row6" class="row_heading level0 row6" >RidgeClassifierCV</th>
#       <td id="T_693e8_row6_col0" class="data row6 col0" >0.783333</td>
#       <td id="T_693e8_row6_col1" class="data row6 col1" >0.726496</td>
#       <td id="T_693e8_row6_col2" class="data row6 col2" >0.726496</td>
#       <td id="T_693e8_row6_col3" class="data row6 col3" >0.857619</td>
#       <td id="T_693e8_row6_col4" class="data row6 col4" >0.041256</td>
#     </tr>
#     <tr>
#       <th id="T_693e8_level0_row7" class="row_heading level0 row7" >RidgeClassifier</th>
#       <td id="T_693e8_row7_col0" class="data row7 col0" >0.783333</td>
#       <td id="T_693e8_row7_col1" class="data row7 col1" >0.726496</td>
#       <td id="T_693e8_row7_col2" class="data row7 col2" >0.726496</td>
#       <td id="T_693e8_row7_col3" class="data row7 col3" >0.857619</td>
#       <td id="T_693e8_row7_col4" class="data row7 col4" >0.015988</td>
#     </tr>
#     <tr>
#       <th id="T_693e8_level0_row8" class="row_heading level0 row8" >Perceptron</th>
#       <td id="T_693e8_row8_col0" class="data row8 col0" >0.758333</td>
#       <td id="T_693e8_row8_col1" class="data row8 col1" >0.713675</td>
#       <td id="T_693e8_row8_col2" class="data row8 col2" >0.713675</td>
#       <td id="T_693e8_row8_col3" class="data row8 col3" >0.841436</td>
#       <td id="T_693e8_row8_col4" class="data row8 col4" >0.016200</td>
#     </tr>
#     <tr>
#       <th id="T_693e8_level0_row9" class="row_heading level0 row9" >BernoulliNB</th>
#       <td id="T_693e8_row9_col0" class="data row9 col0" >0.750000<
# Selected patient ID:  [71]
# X_train shape:  (1790, 61)
# X_test shape:  (169, 61)
# y_train shape:  (1790,)
# y_test shape:  (169,)
# 100%|███████████████████████████████████████████| 29/29 [00:08<00:00,  3.50it/s]
# <style type="text/css">
# #T_dda6f_row0_col0, #T_dda6f_row0_col1, #T_dda6f_row0_col2, #T_dda6f_row0_col3, #T_dda6f_row0_col4, #T_dda6f_row1_col0, #T_dda6f_row1_col1, #T_dda6f_row1_col2, #T_dda6f_row1_col3, #T_dda6f_row1_col4, #T_dda6f_row2_col0, #T_dda6f_row2_col1, #T_dda6f_row2_col2, #T_dda6f_row2_col3, #T_dda6f_row2_col4, #T_dda6f_row3_col0, #T_dda6f_row3_col1, #T_dda6f_row3_col2, #T_dda6f_row3_col3, #T_dda6f_row3_col4, #T_dda6f_row4_col0, #T_dda6f_row4_col1, #T_dda6f_row4_col2, #T_dda6f_row4_col3, #T_dda6f_row4_col4, #T_dda6f_row5_col0, #T_dda6f_row5_col1, #T_dda6f_row5_col2, #T_dda6f_row5_col3, #T_dda6f_row5_col4, #T_dda6f_row6_col0, #T_dda6f_row6_col1, #T_dda6f_row6_col2, #T_dda6f_row6_col3, #T_dda6f_row6_col4, #T_dda6f_row7_col0, #T_dda6f_row7_col1, #T_dda6f_row7_col2, #T_dda6f_row7_col3, #T_dda6f_row7_col4, #T_dda6f_row8_col0, #T_dda6f_row8_col1, #T_dda6f_row8_col2, #T_dda6f_row8_col3, #T_dda6f_row8_col4, #T_dda6f_row9_col0, #T_dda6f_row9_col1, #T_dda6f_row9_col2, #T_dda6f_row9_col3, #T_dda6f_row9_col4, #T_dda6f_row10_col0, #T_dda6f_row10_col1, #T_dda6f_row10_col2, #T_dda6f_row10_col3, #T_dda6f_row10_col4, #T_dda6f_row11_col0, #T_dda6f_row11_col1, #T_dda6f_row11_col2, #T_dda6f_row11_col3, #T_dda6f_row11_col4, #T_dda6f_row12_col0, #T_dda6f_row12_col1, #T_dda6f_row12_col2, #T_dda6f_row12_col3, #T_dda6f_row12_col4, #T_dda6f_row13_col0, #T_dda6f_row13_col1, #T_dda6f_row13_col2, #T_dda6f_row13_col3, #T_dda6f_row13_col4, #T_dda6f_row14_col0, #T_dda6f_row14_col1, #T_dda6f_row14_col2, #T_dda6f_row14_col3, #T_dda6f_row14_col4, #T_dda6f_row15_col0, #T_dda6f_row15_col1, #T_dda6f_row15_col2, #T_dda6f_row15_col3, #T_dda6f_row15_col4, #T_dda6f_row16_col0, #T_dda6f_row16_col1, #T_dda6f_row16_col2, #T_dda6f_row16_col3, #T_dda6f_row16_col4, #T_dda6f_row17_col0, #T_dda6f_row17_col1, #T_dda6f_row17_col2, #T_dda6f_row17_col3, #T_dda6f_row17_col4, #T_dda6f_row18_col0, #T_dda6f_row18_col1, #T_dda6f_row18_col2, #T_dda6f_row18_col3, #T_dda6f_row18_col4, #T_dda6f_row19_col0, #T_dda6f_row19_col1, #T_dda6f_row19_col2, #T_dda6f_row19_col3, #T_dda6f_row19_col4, #T_dda6f_row20_col0, #T_dda6f_row20_col1, #T_dda6f_row20_col2, #T_dda6f_row20_col3, #T_dda6f_row20_col4, #T_dda6f_row21_col0, #T_dda6f_row21_col1, #T_dda6f_row21_col2, #T_dda6f_row21_col3, #T_dda6f_row21_col4, #T_dda6f_row22_col0, #T_dda6f_row22_col1, #T_dda6f_row22_col2, #T_dda6f_row22_col3, #T_dda6f_row22_col4, #T_dda6f_row23_col0, #T_dda6f_row23_col1, #T_dda6f_row23_col2, #T_dda6f_row23_col3, #T_dda6f_row23_col4, #T_dda6f_row24_col0, #T_dda6f_row24_col1, #T_dda6f_row24_col2, #T_dda6f_row24_col3, #T_dda6f_row24_col4, #T_dda6f_row25_col0, #T_dda6f_row25_col1, #T_dda6f_row25_col2, #T_dda6f_row25_col3, #T_dda6f_row25_col4, #T_dda6f_row26_col0, #T_dda6f_row26_col1, #T_dda6f_row26_col2, #T_dda6f_row26_col3, #T_dda6f_row26_col4 {
#   font-size: 9pt;
# }
# </style>
# <table id="T_dda6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dda6f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_dda6f_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_dda6f_level0_col2" class="col_heading level0 col2" >ROC AUC</th>
#       <th id="T_dda6f_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_dda6f_level0_col4" class="col_heading level0 col4" >Time Taken</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dda6f_level0_row0" class="row_heading level0 row0" >BaggingClassifier</th>
#       <td id="T_dda6f_row0_col0" class="data row0 col0" >0.970414</td>
#       <td id="T_dda6f_row0_col1" class="data row0 col1" >0.887805</td>
#       <td id="T_dda6f_row0_col2" class="data row0 col2" >0.887805</td>
#       <td id="T_dda6f_row0_col3" class="data row0 col3" >0.973691</td>
#       <td id="T_dda6f_row0_col4" class="data row0 col4" >1.152354</td>
#     </tr>
#     <tr>
#       <th id="T_dda6f_level0_row1" class="row_heading level0 row1" >AdaBoostClassifier</th>
#       <td id="T_dda6f_row1_col0" class="data row1 col0" >0.917160</td>
#       <td id="T_dda6f_row1_col1" class="data row1 col1" >0.860366</td>
#       <td id="T_dda6f_row1_col2" class="data row1 col2" >0.860366</td>
#       <td id="T_dda6f_row1_col3" class="data row1 col3" >0.938180</td>
#       <td id="T_dda6f_row1_col4" class="data row1 col4" >0.990874</td>
#     </tr>
#     <tr>
#       <th id="T_dda6f_level0_row2" class="row_heading level0 row2" >SGDClassifier</th>
#       <td id="T_dda6f_row2_col0" class="data row2 col0" >0.834320</td>
#       <td id="T_dda6f_row2_col1" class="data row2 col1" >0.817683</td>
#       <td id="T_dda6f_row2_col2" class="data row2 col2" >0.817683</td>
#       <td id="T_dda6f_row2_col3" class="data row2 col3" >0.887017</td>
#       <td id="T_dda6f_row2_col4" class="data row2 col4" >0.073406</td>
#     </tr>
#     <tr>
#       <th id="T_dda6f_level0_row3" class="row_heading level0 row3" >GaussianNB</th>
#       <td id="T_dda6f_row3_col0" class="data row3 col0" >0.704142</td>
#       <td id="T_dda6f_row3_col1" class="data row3 col1" >0.750610</td>
#       <td id="T_dda6f_row3_col2" class="data row3 col2" >0.750610</td>
#       <td id="T_dda6f_row3_col3" class="data row3 col3" >0.801207</td>
#       <td id="T_dda6f_row3_col4" class="data row3 col4" >0.012548</td>
#     </tr>
#     <tr>
#       <th id="T_dda6f_level0_row4" class="row_heading level0 row4" >LinearDiscriminantAnalysis</th>
#       <td id="T_dda6f_row4_col0" class="data row4 col0" >0.804734</td>
#       <td id="T_dda6f_row4_col1" class="data row4 col1" >0.705488</td>
#       <td id="T_dda6f_row4_col2" class="data row4 col2" >0.705488</td>
#       <td id="T_dda6f_row4_col3" class="data row4 col3" >0.867863</td>
#       <td id="T_dda6f_row4_col4" class="data row4 col4" >0.053780</td>
#     </tr>
#     <tr>
#       <th id="T_dda6f_level0_row5" class="row_heading level0 row5" >RidgeClassifierCV</th>
#       <td id="T_dda6f_row5_col0" class="data row5 col0" >0.804734</td>
#       <td id="T_dda6f_row5_col1" class="data row5 col1" >0.705488</td>
#       <td id="T_dda6f_row5_col2" class="data row5 col2" >0.705488</td>
#       <td id="T_dda6f_row5_col3" class="data row5 col3" >0.867863</td>
#       <td id="T_dda6f_row5_col4" class="data row5 col4" >0.042861</td>
#     </tr>
#     <tr>
#       <th id="T_dda6f_level0_row6" class="row_heading level0 row6" >RidgeClassifier</th>
#       <td id="T_dda6f_row6_col0" class="data row6 col0" >0.804734</td>
#       <td id="T_dda6f_row6_col1" class="data row6 col1" >0.705488</td>
#       <td id="T_dda6f_row6_col2" class="data row6 col2" >0.705488</td>
#       <td id="T_dda6f_row6_col3" class="data row6 col3" >0.867863</td>
#       <td id="T_dda6f_row6_col4" class="data row6 col4" >0.016789</td>
#     </tr>
#     <tr>
#       <th id="T_dda6f_level0_row7" class="row_heading level0 row7" >PassiveAggressiveClassifier</th>
#       <td id="T_dda6f_row7_col0" class="data row7 col0" >0.781065</td>
#       <td id="T_dda6f_row7_col1" class="data row7 col1" >0.693293</td>
#       <td id="T_dda6f_row7_col2" class="data row7 col2" >0.693293</td>
#       <td id="T_dda6f_row7_col3" class="data row7 col3" >0.852829</td>
#       <td id="T_dda6f_row7_col4" class="data row7 col4" >0.020796</td>
#     </tr>
#     <tr>
#       <th id="T_dda6f_level0_row8" class="row_heading level0 row8" >XGBClassifier</th>
#       <td id="T_dda6f_row8_col0" class="data row8 col0" >0.952663</td>
#       <td id="T_dda6f_row8_col1" class="data row8 col1" >0.684756</td>
#       <td id="T_dda6f_row8_col2" class="data row8 col2" >0.684756</td>
#       <td id="T_dda6f_row8_col3" class="data row8 col3" >0.956462</td>
#       <td id="T_dda6f_row8_col4" class="data row8 col4" >0.323630</td>
#     </tr>
#     <tr>
#       <th id="T_dda6f_level0_row9" class="row_heading level0 row9" >LGBMClassifier</th>
#       <td id="T_dda6f_row9_col0" class="data row9 col0" >0.93491
# Selected patient ID:  [77]
# X_train shape:  (1791, 61)
# X_test shape:  (168, 61)
# y_train shape:  (1791,)
# y_test shape:  (168,)
# 100%|███████████████████████████████████████████| 29/29 [00:08<00:00,  3.37it/s]
# <style type="text/css">
# #T_28762_row0_col0, #T_28762_row0_col1, #T_28762_row0_col2, #T_28762_row0_col3, #T_28762_row0_col4, #T_28762_row1_col0, #T_28762_row1_col1, #T_28762_row1_col2, #T_28762_row1_col3, #T_28762_row1_col4, #T_28762_row2_col0, #T_28762_row2_col1, #T_28762_row2_col2, #T_28762_row2_col3, #T_28762_row2_col4, #T_28762_row3_col0, #T_28762_row3_col1, #T_28762_row3_col2, #T_28762_row3_col3, #T_28762_row3_col4, #T_28762_row4_col0, #T_28762_row4_col1, #T_28762_row4_col2, #T_28762_row4_col3, #T_28762_row4_col4, #T_28762_row5_col0, #T_28762_row5_col1, #T_28762_row5_col2, #T_28762_row5_col3, #T_28762_row5_col4, #T_28762_row6_col0, #T_28762_row6_col1, #T_28762_row6_col2, #T_28762_row6_col3, #T_28762_row6_col4, #T_28762_row7_col0, #T_28762_row7_col1, #T_28762_row7_col2, #T_28762_row7_col3, #T_28762_row7_col4, #T_28762_row8_col0, #T_28762_row8_col1, #T_28762_row8_col2, #T_28762_row8_col3, #T_28762_row8_col4, #T_28762_row9_col0, #T_28762_row9_col1, #T_28762_row9_col2, #T_28762_row9_col3, #T_28762_row9_col4, #T_28762_row10_col0, #T_28762_row10_col1, #T_28762_row10_col2, #T_28762_row10_col3, #T_28762_row10_col4, #T_28762_row11_col0, #T_28762_row11_col1, #T_28762_row11_col2, #T_28762_row11_col3, #T_28762_row11_col4, #T_28762_row12_col0, #T_28762_row12_col1, #T_28762_row12_col2, #T_28762_row12_col3, #T_28762_row12_col4, #T_28762_row13_col0, #T_28762_row13_col1, #T_28762_row13_col2, #T_28762_row13_col3, #T_28762_row13_col4, #T_28762_row14_col0, #T_28762_row14_col1, #T_28762_row14_col2, #T_28762_row14_col3, #T_28762_row14_col4, #T_28762_row15_col0, #T_28762_row15_col1, #T_28762_row15_col2, #T_28762_row15_col3, #T_28762_row15_col4, #T_28762_row16_col0, #T_28762_row16_col1, #T_28762_row16_col2, #T_28762_row16_col3, #T_28762_row16_col4, #T_28762_row17_col0, #T_28762_row17_col1, #T_28762_row17_col2, #T_28762_row17_col3, #T_28762_row17_col4, #T_28762_row18_col0, #T_28762_row18_col1, #T_28762_row18_col2, #T_28762_row18_col3, #T_28762_row18_col4, #T_28762_row19_col0, #T_28762_row19_col1, #T_28762_row19_col2, #T_28762_row19_col3, #T_28762_row19_col4, #T_28762_row20_col0, #T_28762_row20_col1, #T_28762_row20_col2, #T_28762_row20_col3, #T_28762_row20_col4, #T_28762_row21_col0, #T_28762_row21_col1, #T_28762_row21_col2, #T_28762_row21_col3, #T_28762_row21_col4, #T_28762_row22_col0, #T_28762_row22_col1, #T_28762_row22_col2, #T_28762_row22_col3, #T_28762_row22_col4, #T_28762_row23_col0, #T_28762_row23_col1, #T_28762_row23_col2, #T_28762_row23_col3, #T_28762_row23_col4, #T_28762_row24_col0, #T_28762_row24_col1, #T_28762_row24_col2, #T_28762_row24_col3, #T_28762_row24_col4, #T_28762_row25_col0, #T_28762_row25_col1, #T_28762_row25_col2, #T_28762_row25_col3, #T_28762_row25_col4, #T_28762_row26_col0, #T_28762_row26_col1, #T_28762_row26_col2, #T_28762_row26_col3, #T_28762_row26_col4 {
#   font-size: 9pt;
# }
# </style>
# <table id="T_28762">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28762_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_28762_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_28762_level0_col2" class="col_heading level0 col2" >ROC AUC</th>
#       <th id="T_28762_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_28762_level0_col4" class="col_heading level0 col4" >Time Taken</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28762_level0_row0" class="row_heading level0 row0" >LGBMClassifier</th>
#       <td id="T_28762_row0_col0" class="data row0 col0" >0.988095</td>
#       <td id="T_28762_row0_col1" class="data row0 col1" >0.993976</td>
#       <td id="T_28762_row0_col2" class="data row0 col2" >0.993976</td>
#       <td id="T_28762_row0_col3" class="data row0 col3" >0.990043</td>
#       <td id="T_28762_row0_col4" class="data row0 col4" >0.185447</td>
#     </tr>
#     <tr>
#       <th id="T_28762_level0_row1" class="row_heading level0 row1" >RandomForestClassifier</th>
#       <td id="T_28762_row1_col0" class="data row1 col0" >0.982143</td>
#       <td id="T_28762_row1_col1" class="data row1 col1" >0.990964</td>
#       <td id="T_28762_row1_col2" class="data row1 col2" >0.990964</td>
#       <td id="T_28762_row1_col3" class="data row1 col3" >0.985888</td>
#       <td id="T_28762_row1_col4" class="data row1 col4" >1.378026</td>
#     </tr>
#     <tr>
#       <th id="T_28762_level0_row2" class="row_heading level0 row2" >ExtraTreesClassifier</th>
#       <td id="T_28762_row2_col0" class="data row2 col0" >0.976190</td>
#       <td id="T_28762_row2_col1" class="data row2 col1" >0.987952</td>
#       <td id="T_28762_row2_col2" class="data row2 col2" >0.987952</td>
#       <td id="T_28762_row2_col3" class="data row2 col3" >0.981998</td>
#       <td id="T_28762_row2_col4" class="data row2 col4" >0.298851</td>
#     </tr>
#     <tr>
#       <th id="T_28762_level0_row3" class="row_heading level0 row3" >XGBClassifier</th>
#       <td id="T_28762_row3_col0" class="data row3 col0" >0.970238</td>
#       <td id="T_28762_row3_col1" class="data row3 col1" >0.984940</td>
#       <td id="T_28762_row3_col2" class="data row3 col2" >0.984940</td>
#       <td id="T_28762_row3_col3" class="data row3 col3" >0.978278</td>
#       <td id="T_28762_row3_col4" class="data row3 col4" >0.368887</td>
#     </tr>
#     <tr>
#       <th id="T_28762_level0_row4" class="row_heading level0 row4" >NuSVC</th>
#       <td id="T_28762_row4_col0" class="data row4 col0" >0.946429</td>
#       <td id="T_28762_row4_col1" class="data row4 col1" >0.972892</td>
#       <td id="T_28762_row4_col2" class="data row4 col2" >0.972892</td>
#       <td id="T_28762_row4_col3" class="data row4 col3" >0.964226</td>
#       <td id="T_28762_row4_col4" class="data row4 col4" >0.388267</td>
#     </tr>
#     <tr>
#       <th id="T_28762_level0_row5" class="row_heading level0 row5" >LogisticRegression</th>
#       <td id="T_28762_row5_col0" class="data row5 col0" >0.910714</td>
#       <td id="T_28762_row5_col1" class="data row5 col1" >0.954819</td>
#       <td id="T_28762_row5_col2" class="data row5 col2" >0.954819</td>
#       <td id="T_28762_row5_col3" class="data row5 col3" >0.943846</td>
#       <td id="T_28762_row5_col4" class="data row5 col4" >0.050304</td>
#     </tr>
#     <tr>
#       <th id="T_28762_level0_row6" class="row_heading level0 row6" >CalibratedClassifierCV</th>
#       <td id="T_28762_row6_col0" class="data row6 col0" >0.898810</td>
#       <td id="T_28762_row6_col1" class="data row6 col1" >0.948795</td>
#       <td id="T_28762_row6_col2" class="data row6 col2" >0.948795</td>
#       <td id="T_28762_row6_col3" class="data row6 col3" >0.937037</td>
#       <td id="T_28762_row6_col4" class="data row6 col4" >1.331754</td>
#     </tr>
#     <tr>
#       <th id="T_28762_level0_row7" class="row_heading level0 row7" >LinearSVC</th>
#       <td id="T_28762_row7_col0" class="data row7 col0" >0.892857</td>
#       <td id="T_28762_row7_col1" class="data row7 col1" >0.945783</td>
#       <td id="T_28762_row7_col2" class="data row7 col2" >0.945783</td>
#       <td id="T_28762_row7_col3" class="data row7 col3" >0.933617</td>
#       <td id="T_28762_row7_col4" class="data row7 col4" >0.402790</td>
#     </tr>
#     <tr>
#       <th id="T_28762_level0_row8" class="row_heading level0 row8" >AdaBoostClassifier</th>
#       <td id="T_28762_row8_col0" class="data row8 col0" >0.880952</td>
#       <td id="T_28762_row8_col1" class="data row8 col1" >0.939759</td>
#       <td id="T_28762_row8_col2" class="data row8 col2" >0.939759</td>
#       <td id="T_28762_row8_col3" class="data row8 col3" >0.926740</td>
#       <td id="T_28762_row8_col4" class="data row8 col4" >1.003282</td>
#     </tr>
#     <tr>
#       <th id="T_28762_level0_row9" class="row_heading level0 row9" >RidgeClassifierCV</th>
#       <td id="T_28762_row9_col0" class="data row9 col0" >0.851190</td>
# Selected patient ID:  [82]
# X_train shape:  (1874, 61)
# X_test shape:  (85, 61)
# y_train shape:  (1874,)
# y_test shape:  (85,)
# 100%|███████████████████████████████████████████| 29/29 [00:08<00:00,  3.30it/s]
# <style type="text/css">
# #T_740ef_row0_col0, #T_740ef_row0_col1, #T_740ef_row0_col2, #T_740ef_row0_col3, #T_740ef_row0_col4, #T_740ef_row1_col0, #T_740ef_row1_col1, #T_740ef_row1_col2, #T_740ef_row1_col3, #T_740ef_row1_col4, #T_740ef_row2_col0, #T_740ef_row2_col1, #T_740ef_row2_col2, #T_740ef_row2_col3, #T_740ef_row2_col4, #T_740ef_row3_col0, #T_740ef_row3_col1, #T_740ef_row3_col2, #T_740ef_row3_col3, #T_740ef_row3_col4, #T_740ef_row4_col0, #T_740ef_row4_col1, #T_740ef_row4_col2, #T_740ef_row4_col3, #T_740ef_row4_col4, #T_740ef_row5_col0, #T_740ef_row5_col1, #T_740ef_row5_col2, #T_740ef_row5_col3, #T_740ef_row5_col4, #T_740ef_row6_col0, #T_740ef_row6_col1, #T_740ef_row6_col2, #T_740ef_row6_col3, #T_740ef_row6_col4, #T_740ef_row7_col0, #T_740ef_row7_col1, #T_740ef_row7_col2, #T_740ef_row7_col3, #T_740ef_row7_col4, #T_740ef_row8_col0, #T_740ef_row8_col1, #T_740ef_row8_col2, #T_740ef_row8_col3, #T_740ef_row8_col4, #T_740ef_row9_col0, #T_740ef_row9_col1, #T_740ef_row9_col2, #T_740ef_row9_col3, #T_740ef_row9_col4, #T_740ef_row10_col0, #T_740ef_row10_col1, #T_740ef_row10_col2, #T_740ef_row10_col3, #T_740ef_row10_col4, #T_740ef_row11_col0, #T_740ef_row11_col1, #T_740ef_row11_col2, #T_740ef_row11_col3, #T_740ef_row11_col4, #T_740ef_row12_col0, #T_740ef_row12_col1, #T_740ef_row12_col2, #T_740ef_row12_col3, #T_740ef_row12_col4, #T_740ef_row13_col0, #T_740ef_row13_col1, #T_740ef_row13_col2, #T_740ef_row13_col3, #T_740ef_row13_col4, #T_740ef_row14_col0, #T_740ef_row14_col1, #T_740ef_row14_col2, #T_740ef_row14_col3, #T_740ef_row14_col4, #T_740ef_row15_col0, #T_740ef_row15_col1, #T_740ef_row15_col2, #T_740ef_row15_col3, #T_740ef_row15_col4, #T_740ef_row16_col0, #T_740ef_row16_col1, #T_740ef_row16_col2, #T_740ef_row16_col3, #T_740ef_row16_col4, #T_740ef_row17_col0, #T_740ef_row17_col1, #T_740ef_row17_col2, #T_740ef_row17_col3, #T_740ef_row17_col4, #T_740ef_row18_col0, #T_740ef_row18_col1, #T_740ef_row18_col2, #T_740ef_row18_col3, #T_740ef_row18_col4, #T_740ef_row19_col0, #T_740ef_row19_col1, #T_740ef_row19_col2, #T_740ef_row19_col3, #T_740ef_row19_col4, #T_740ef_row20_col0, #T_740ef_row20_col1, #T_740ef_row20_col2, #T_740ef_row20_col3, #T_740ef_row20_col4, #T_740ef_row21_col0, #T_740ef_row21_col1, #T_740ef_row21_col2, #T_740ef_row21_col3, #T_740ef_row21_col4, #T_740ef_row22_col0, #T_740ef_row22_col1, #T_740ef_row22_col2, #T_740ef_row22_col3, #T_740ef_row22_col4, #T_740ef_row23_col0, #T_740ef_row23_col1, #T_740ef_row23_col2, #T_740ef_row23_col3, #T_740ef_row23_col4, #T_740ef_row24_col0, #T_740ef_row24_col1, #T_740ef_row24_col2, #T_740ef_row24_col3, #T_740ef_row24_col4, #T_740ef_row25_col0, #T_740ef_row25_col1, #T_740ef_row25_col2, #T_740ef_row25_col3, #T_740ef_row25_col4, #T_740ef_row26_col0, #T_740ef_row26_col1, #T_740ef_row26_col2, #T_740ef_row26_col3, #T_740ef_row26_col4 {
#   font-size: 9pt;
# }
# </style>
# <table id="T_740ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_740ef_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_740ef_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_740ef_level0_col2" class="col_heading level0 col2" >ROC AUC</th>
#       <th id="T_740ef_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_740ef_level0_col4" class="col_heading level0 col4" >Time Taken</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_740ef_level0_row0" class="row_heading level0 row0" >DecisionTreeClassifier</th>
#       <td id="T_740ef_row0_col0" class="data row0 col0" >0.776471</td>
#       <td id="T_740ef_row0_col1" class="data row0 col1" >0.562039</td>
#       <td id="T_740ef_row0_col2" class="data row0 col2" >0.562039</td>
#       <td id="T_740ef_row0_col3" class="data row0 col3" >0.787570</td>
#       <td id="T_740ef_row0_col4" class="data row0 col4" >0.281519</td>
#     </tr>
#     <tr>
#       <th id="T_740ef_level0_row1" class="row_heading level0 row1" >KNeighborsClassifier</th>
#       <td id="T_740ef_row1_col0" class="data row1 col0" >0.694118</td>
#       <td id="T_740ef_row1_col1" class="data row1 col1" >0.553440</td>
#       <td id="T_740ef_row1_col2" class="data row1 col2" >0.553440</td>
#       <td id="T_740ef_row1_col3" class="data row1 col3" >0.734602</td>
#       <td id="T_740ef_row1_col4" class="data row1 col4" >0.014535</td>
#     </tr>
#     <tr>
#       <th id="T_740ef_level0_row2" class="row_heading level0 row2" >AdaBoostClassifier</th>
#       <td id="T_740ef_row2_col0" class="data row2 col0" >0.823529</td>
#       <td id="T_740ef_row2_col1" class="data row2 col1" >0.550369</td>
#       <td id="T_740ef_row2_col2" class="data row2 col2" >0.550369</td>
#       <td id="T_740ef_row2_col3" class="data row2 col3" >0.811351</td>
#       <td id="T_740ef_row2_col4" class="data row2 col4" >1.043661</td>
#     </tr>
#     <tr>
#       <th id="T_740ef_level0_row3" class="row_heading level0 row3" >PassiveAggressiveClassifier</th>
#       <td id="T_740ef_row3_col0" class="data row3 col0" >0.611765</td>
#       <td id="T_740ef_row3_col1" class="data row3 col1" >0.544840</td>
#       <td id="T_740ef_row3_col2" class="data row3 col2" >0.544840</td>
#       <td id="T_740ef_row3_col3" class="data row3 col3" >0.674468</td>
#       <td id="T_740ef_row3_col4" class="data row3 col4" >0.020714</td>
#     </tr>
#     <tr>
#       <th id="T_740ef_level0_row4" class="row_heading level0 row4" >BernoulliNB</th>
#       <td id="T_740ef_row4_col0" class="data row4 col0" >0.741176</td>
#       <td id="T_740ef_row4_col1" class="data row4 col1" >0.541769</td>
#       <td id="T_740ef_row4_col2" class="data row4 col2" >0.541769</td>
#       <td id="T_740ef_row4_col3" class="data row4 col3" >0.763439</td>
#       <td id="T_740ef_row4_col4" class="data row4 col4" >0.015367</td>
#     </tr>
#     <tr>
#       <th id="T_740ef_level0_row5" class="row_heading level0 row5" >GaussianNB</th>
#       <td id="T_740ef_row5_col0" class="data row5 col0" >0.600000</td>
#       <td id="T_740ef_row5_col1" class="data row5 col1" >0.538084</td>
#       <td id="T_740ef_row5_col2" class="data row5 col2" >0.538084</td>
#       <td id="T_740ef_row5_col3" class="data row5 col3" >0.665079</td>
#       <td id="T_740ef_row5_col4" class="data row5 col4" >0.013057</td>
#     </tr>
#     <tr>
#       <th id="T_740ef_level0_row6" class="row_heading level0 row6" >NearestCentroid</th>
#       <td id="T_740ef_row6_col0" class="data row6 col0" >0.658824</td>
#       <td id="T_740ef_row6_col1" class="data row6 col1" >0.533170</td>
#       <td id="T_740ef_row6_col2" class="data row6 col2" >0.533170</td>
#       <td id="T_740ef_row6_col3" class="data row6 col3" >0.708742</td>
#       <td id="T_740ef_row6_col4" class="data row6 col4" >0.014265</td>
#     </tr>
#     <tr>
#       <th id="T_740ef_level0_row7" class="row_heading level0 row7" >LGBMClassifier</th>
#       <td id="T_740ef_row7_col0" class="data row7 col0" >0.858824</td>
#       <td id="T_740ef_row7_col1" class="data row7 col1" >0.531941</td>
#       <td id="T_740ef_row7_col2" class="data row7 col2" >0.531941</td>
#       <td id="T_740ef_row7_col3" class="data row7 col3" >0.822107</td>
#       <td id="T_740ef_row7_col4" class="data row7 col4" >0.189023</td>
#     </tr>
#     <tr>
#       <th id="T_740ef_level0_row8" class="row_heading level0 row8" >CalibratedClassifierCV</th>
#       <td id="T_740ef_row8_col0" class="data row8 col0" >0.717647</td>
#       <td id="T_740ef_row8_col1" class="data row8 col1" >0.528256</td>
#       <td id="T_740ef_row8_col2" class="data row8 col2" >0.528256</td>
#       <td id="T_740ef_row8_col3" class="data row8 col3" >0.747227</td>
#       <td id="T_740ef_row8_col4" class="data row8 col4" >1.367205</td>
#     </tr>
#     <tr>
#       <th id="T_740ef_level0_row9" class="row_heading level0 row9" >LogisticRegression</th>
#       <td id="T_740ef_row9_col0" class="data row9 col0" >
# Selected patient ID:  [89]
# X_train shape:  (1789, 61)
# X_test shape:  (170, 61)
# y_train shape:  (1789,)
# y_test shape:  (170,)
# 100%|███████████████████████████████████████████| 29/29 [00:08<00:00,  3.50it/s]
# <style type="text/css">
# #T_0677c_row0_col0, #T_0677c_row0_col1, #T_0677c_row0_col2, #T_0677c_row0_col3, #T_0677c_row0_col4, #T_0677c_row1_col0, #T_0677c_row1_col1, #T_0677c_row1_col2, #T_0677c_row1_col3, #T_0677c_row1_col4, #T_0677c_row2_col0, #T_0677c_row2_col1, #T_0677c_row2_col2, #T_0677c_row2_col3, #T_0677c_row2_col4, #T_0677c_row3_col0, #T_0677c_row3_col1, #T_0677c_row3_col2, #T_0677c_row3_col3, #T_0677c_row3_col4, #T_0677c_row4_col0, #T_0677c_row4_col1, #T_0677c_row4_col2, #T_0677c_row4_col3, #T_0677c_row4_col4, #T_0677c_row5_col0, #T_0677c_row5_col1, #T_0677c_row5_col2, #T_0677c_row5_col3, #T_0677c_row5_col4, #T_0677c_row6_col0, #T_0677c_row6_col1, #T_0677c_row6_col2, #T_0677c_row6_col3, #T_0677c_row6_col4, #T_0677c_row7_col0, #T_0677c_row7_col1, #T_0677c_row7_col2, #T_0677c_row7_col3, #T_0677c_row7_col4, #T_0677c_row8_col0, #T_0677c_row8_col1, #T_0677c_row8_col2, #T_0677c_row8_col3, #T_0677c_row8_col4, #T_0677c_row9_col0, #T_0677c_row9_col1, #T_0677c_row9_col2, #T_0677c_row9_col3, #T_0677c_row9_col4, #T_0677c_row10_col0, #T_0677c_row10_col1, #T_0677c_row10_col2, #T_0677c_row10_col3, #T_0677c_row10_col4, #T_0677c_row11_col0, #T_0677c_row11_col1, #T_0677c_row11_col2, #T_0677c_row11_col3, #T_0677c_row11_col4, #T_0677c_row12_col0, #T_0677c_row12_col1, #T_0677c_row12_col2, #T_0677c_row12_col3, #T_0677c_row12_col4, #T_0677c_row13_col0, #T_0677c_row13_col1, #T_0677c_row13_col2, #T_0677c_row13_col3, #T_0677c_row13_col4, #T_0677c_row14_col0, #T_0677c_row14_col1, #T_0677c_row14_col2, #T_0677c_row14_col3, #T_0677c_row14_col4, #T_0677c_row15_col0, #T_0677c_row15_col1, #T_0677c_row15_col2, #T_0677c_row15_col3, #T_0677c_row15_col4, #T_0677c_row16_col0, #T_0677c_row16_col1, #T_0677c_row16_col2, #T_0677c_row16_col3, #T_0677c_row16_col4, #T_0677c_row17_col0, #T_0677c_row17_col1, #T_0677c_row17_col2, #T_0677c_row17_col3, #T_0677c_row17_col4, #T_0677c_row18_col0, #T_0677c_row18_col1, #T_0677c_row18_col2, #T_0677c_row18_col3, #T_0677c_row18_col4, #T_0677c_row19_col0, #T_0677c_row19_col1, #T_0677c_row19_col2, #T_0677c_row19_col3, #T_0677c_row19_col4, #T_0677c_row20_col0, #T_0677c_row20_col1, #T_0677c_row20_col2, #T_0677c_row20_col3, #T_0677c_row20_col4, #T_0677c_row21_col0, #T_0677c_row21_col1, #T_0677c_row21_col2, #T_0677c_row21_col3, #T_0677c_row21_col4, #T_0677c_row22_col0, #T_0677c_row22_col1, #T_0677c_row22_col2, #T_0677c_row22_col3, #T_0677c_row22_col4, #T_0677c_row23_col0, #T_0677c_row23_col1, #T_0677c_row23_col2, #T_0677c_row23_col3, #T_0677c_row23_col4, #T_0677c_row24_col0, #T_0677c_row24_col1, #T_0677c_row24_col2, #T_0677c_row24_col3, #T_0677c_row24_col4, #T_0677c_row25_col0, #T_0677c_row25_col1, #T_0677c_row25_col2, #T_0677c_row25_col3, #T_0677c_row25_col4, #T_0677c_row26_col0, #T_0677c_row26_col1, #T_0677c_row26_col2, #T_0677c_row26_col3, #T_0677c_row26_col4 {
#   font-size: 9pt;
# }
# </style>
# <table id="T_0677c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0677c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0677c_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_0677c_level0_col2" class="col_heading level0 col2" >ROC AUC</th>
#       <th id="T_0677c_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_0677c_level0_col4" class="col_heading level0 col4" >Time Taken</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0677c_level0_row0" class="row_heading level0 row0" >BernoulliNB</th>
#       <td id="T_0677c_row0_col0" class="data row0 col0" >0.776471</td>
#       <td id="T_0677c_row0_col1" class="data row0 col1" >0.704475</td>
#       <td id="T_0677c_row0_col2" class="data row0 col2" >0.704475</td>
#       <td id="T_0677c_row0_col3" class="data row0 col3" >0.838732</td>
#       <td id="T_0677c_row0_col4" class="data row0 col4" >0.015113</td>
#     </tr>
#     <tr>
#       <th id="T_0677c_level0_row1" class="row_heading level0 row1" >NearestCentroid</th>
#       <td id="T_0677c_row1_col0" class="data row1 col0" >0.676471</td>
#       <td id="T_0677c_row1_col1" class="data row1 col1" >0.652006</td>
#       <td id="T_0677c_row1_col2" class="data row1 col2" >0.652006</td>
#       <td id="T_0677c_row1_col3" class="data row1 col3" >0.769593</td>
#       <td id="T_0677c_row1_col4" class="data row1 col4" >0.013811</td>
#     </tr>
#     <tr>
#       <th id="T_0677c_level0_row2" class="row_heading level0 row2" >DecisionTreeClassifier</th>
#       <td id="T_0677c_row2_col0" class="data row2 col0" >0.888235</td>
#       <td id="T_0677c_row2_col1" class="data row2 col1" >0.644290</td>
#       <td id="T_0677c_row2_col2" class="data row2 col2" >0.644290</td>
#       <td id="T_0677c_row2_col3" class="data row2 col3" >0.906756</td>
#       <td id="T_0677c_row2_col4" class="data row2 col4" >0.254235</td>
#     </tr>
#     <tr>
#       <th id="T_0677c_level0_row3" class="row_heading level0 row3" >GaussianNB</th>
#       <td id="T_0677c_row3_col0" class="data row3 col0" >0.605882</td>
#       <td id="T_0677c_row3_col1" class="data row3 col1" >0.614969</td>
#       <td id="T_0677c_row3_col2" class="data row3 col2" >0.614969</td>
#       <td id="T_0677c_row3_col3" class="data row3 col3" >0.716288</td>
#       <td id="T_0677c_row3_col4" class="data row3 col4" >0.013312</td>
#     </tr>
#     <tr>
#       <th id="T_0677c_level0_row4" class="row_heading level0 row4" >BaggingClassifier</th>
#       <td id="T_0677c_row4_col0" class="data row4 col0" >0.941176</td>
#       <td id="T_0677c_row4_col1" class="data row4 col1" >0.612654</td>
#       <td id="T_0677c_row4_col2" class="data row4 col2" >0.612654</td>
#       <td id="T_0677c_row4_col3" class="data row4 col3" >0.937155</td>
#       <td id="T_0677c_row4_col4" class="data row4 col4" >1.275943</td>
#     </tr>
#     <tr>
#       <th id="T_0677c_level0_row5" class="row_heading level0 row5" >Perceptron</th>
#       <td id="T_0677c_row5_col0" class="data row5 col0" >0.764706</td>
#       <td id="T_0677c_row5_col1" class="data row5 col1" >0.579475</td>
#       <td id="T_0677c_row5_col2" class="data row5 col2" >0.579475</td>
#       <td id="T_0677c_row5_col3" class="data row5 col3" >0.829427</td>
#       <td id="T_0677c_row5_col4" class="data row5 col4" >0.020118</td>
#     </tr>
#     <tr>
#       <th id="T_0677c_level0_row6" class="row_heading level0 row6" >AdaBoostClassifier</th>
#       <td id="T_0677c_row6_col0" class="data row6 col0" >0.852941</td>
#       <td id="T_0677c_row6_col1" class="data row6 col1" >0.566358</td>
#       <td id="T_0677c_row6_col2" class="data row6 col2" >0.566358</td>
# ...
#   font-size: 9pt;
# }
# </style>
# <table id="T_e28c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e28c4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e28c4_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_e28c4_level0_col2" class="col_heading level0 col2" >ROC AUC</th>
#       <th id="T_e28c4_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_e28c4_level0_col4" class="col_heading level0 col4" >Time Taken</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e28c4_level0_row0" class="row_heading level0 row0" >PassiveAggressiveClassifier</th>
#       <td id="T_e28c4_row0_col0" class="data row0 col0" >0.549296</td>
#       <td id="T_e28c4_row0_col1" class="data row0 col1" >0.694444</td>
#       <td id="T_e28c4_row0_col2" class="data row0 col2" >0.694444</td>
#       <td id="T_e28c4_row0_col3" class="data row0 col3" >0.618220</td>
#       <td id="T_e28c4_row0_col4" class="data row0 col4" >0.020264</td>
#     </tr>
#     <tr>
#       <th id="T_e28c4_level0_row1" class="row_heading level0 row1" >AdaBoostClassifier</th>
#       <td id="T_e28c4_row1_col0" class="data row1 col0" >0.732394</td>
#       <td id="T_e28c4_row1_col1" class="data row1 col1" >0.656810</td>
#       <td id="T_e28c4_row1_col2" class="data row1 col2" >0.656810</td>
#       <td id="T_e28c4_row1_col3" class="data row1 col3" >0.770122</td>
#       <td id="T_e28c4_row1_col4" class="data row1 col4" >1.062137</td>
#     </tr>
#     <tr>
#       <th id="T_e28c4_level0_row2" class="row_heading level0 row2" >NuSVC</th>
#       <td id="T_e28c4_row2_col0" class="data row2 col0" >0.788732</td>
#       <td id="T_e28c4_row2_col1" class="data row2 col1" >0.641577</td>
#       <td id="T_e28c4_row2_col2" class="data row2 col2" >0.641577</td>
#       <td id="T_e28c4_row2_col3" class="data row2 col3" >0.807258</td>
#       <td id="T_e28c4_row2_col4" class="data row2 col4" >0.420869</td>
#     </tr>
#     <tr>
#       <th id="T_e28c4_level0_row3" class="row_heading level0 row3" >SGDClassifier</th>
#       <td id="T_e28c4_row3_col0" class="data row3 col0" >0.676056</td>
#       <td id="T_e28c4_row3_col1" class="data row3 col1" >0.624552</td>
#       <td id="T_e28c4_row3_col2" class="data row3 col2" >0.624552</td>
#       <td id="T_e28c4_row3_col3" class="data row3 col3" >0.727390</td>
#       <td id="T_e28c4_row3_col4" class="data row3 col4" >0.052601</td>
#     </tr>
#     <tr>
#       <th id="T_e28c4_level0_row4" class="row_heading level0 row4" >LogisticRegression</th>
#       <td id="T_e28c4_row4_col0" class="data row4 col0" >0.718310</td>
#       <td id="T_e28c4_row4_col1" class="data row4 col1" >0.601254</td>
#       <td id="T_e28c4_row4_col2" class="data row4 col2" >0.601254</td>
#       <td id="T_e28c4_row4_col3" class="data row4 col3" >0.756257</td>
#       <td id="T_e28c4_row4_col4" class="data row4 col4" >0.042193</td>
#     </tr>
#     <tr>
#       <th id="T_e28c4_level0_row5" class="row_heading level0 row5" >SVC</th>
#       <td id="T_e28c4_row5_col0" class="data row5 col0" >0.774648</td>
#       <td id="T_e28c4_row5_col1" class="data row5 col1" >0.586022</td>
#       <td id="T_e28c4_row5_col2" class="data row5 col2" >0.586022</td>
#       <td id="T_e28c4_row5_col3" class="data row5 col3" >0.791379</td>
#       <td id="T_e28c4_row5_col4" class="data row5 col4" >0.238345</td>
#     </tr>
#     <tr>
#       <th id="T_e28c4_level0_row6" class="row_heading level0 row6" >DecisionTreeClassifier</th>
#       <td id="T_e28c4_row6_col0" class="data row6 col0" >0.845070</td>
#       <td id="T_e28c4_row6_col1" class="data row6 col1" >0.578853</td>
#       <td id="T_e28c4_row6_col2" class="data row6 col2" >0.578853</td>
#       <td id="T_e28c4_row6_col3" class="data row6 col3" >0.831407</td>
#       <td id="T_e28c4_row6_col4" class="data row6 col4" >0.268785</td>
#     </tr>
#     <tr>
#       <th id="T_e28c4_level0_row7" class="row_heading level0 row7" >NearestCentroid</th>
#       <td id="T_e28c4_row7_col0" class="data row7 col0" >0.676056</td>
#       <td id="T_e28c4_row7_col1" class="data row7 col1" >0.577061</td>
#       <td id="T_e28c4_row7_col2" class="data row7 col2" >0.577061</td>
#       <td id="T_e28c4_row7_col3" class="data row7 col3" >0.725010</td>
#       <td id="T_e28c4_row7_col4" class="data row7 col4" >0.014082</td>
#     </tr>
#     <tr>
#       <th id="T_e28c4_level0_row8" class="row_heading level0 row8" >ExtraTreeClassifier</th>
#       <td id="T_e28c4_row8_col0" class="data row8 col0" >0.718310</td>
#       <td id="T_e28c4_row8_col1" class="data row8 col1" >0.553763</td>
#       <td id="T_e28c4_row8_col2" class="data row8 col2" >0.553763</td>
#       <td id="T_e28c4_row8_col3" class="data row8 col3" >0.751933</td>
#       <td id="T_e28c4_row8_col4" class="data row8 col4" >0.013292</td>
#     </tr>
#     <tr>
#       <th id="T_e28c4_level0_row9" class="row_heading level0 row9" >CalibratedClassifierCV</th>
#       <td id="T_e28c4_row9_col0" class="data row9 col0" >0.704225</td>
# Selected patient ID:  [1630]
# X_train shape:  (1788, 61)
# X_test shape:  (171, 61)
# y_train shape:  (1788,)
# y_test shape:  (171,)
# 100%|███████████████████████████████████████████| 29/29 [00:08<00:00,  3.48it/s]
# <style type="text/css">
# #T_6d05d_row0_col0, #T_6d05d_row0_col1, #T_6d05d_row0_col2, #T_6d05d_row0_col3, #T_6d05d_row0_col4, #T_6d05d_row1_col0, #T_6d05d_row1_col1, #T_6d05d_row1_col2, #T_6d05d_row1_col3, #T_6d05d_row1_col4, #T_6d05d_row2_col0, #T_6d05d_row2_col1, #T_6d05d_row2_col2, #T_6d05d_row2_col3, #T_6d05d_row2_col4, #T_6d05d_row3_col0, #T_6d05d_row3_col1, #T_6d05d_row3_col2, #T_6d05d_row3_col3, #T_6d05d_row3_col4, #T_6d05d_row4_col0, #T_6d05d_row4_col1, #T_6d05d_row4_col2, #T_6d05d_row4_col3, #T_6d05d_row4_col4, #T_6d05d_row5_col0, #T_6d05d_row5_col1, #T_6d05d_row5_col2, #T_6d05d_row5_col3, #T_6d05d_row5_col4, #T_6d05d_row6_col0, #T_6d05d_row6_col1, #T_6d05d_row6_col2, #T_6d05d_row6_col3, #T_6d05d_row6_col4, #T_6d05d_row7_col0, #T_6d05d_row7_col1, #T_6d05d_row7_col2, #T_6d05d_row7_col3, #T_6d05d_row7_col4, #T_6d05d_row8_col0, #T_6d05d_row8_col1, #T_6d05d_row8_col2, #T_6d05d_row8_col3, #T_6d05d_row8_col4, #T_6d05d_row9_col0, #T_6d05d_row9_col1, #T_6d05d_row9_col2, #T_6d05d_row9_col3, #T_6d05d_row9_col4, #T_6d05d_row10_col0, #T_6d05d_row10_col1, #T_6d05d_row10_col2, #T_6d05d_row10_col3, #T_6d05d_row10_col4, #T_6d05d_row11_col0, #T_6d05d_row11_col1, #T_6d05d_row11_col2, #T_6d05d_row11_col3, #T_6d05d_row11_col4, #T_6d05d_row12_col0, #T_6d05d_row12_col1, #T_6d05d_row12_col2, #T_6d05d_row12_col3, #T_6d05d_row12_col4, #T_6d05d_row13_col0, #T_6d05d_row13_col1, #T_6d05d_row13_col2, #T_6d05d_row13_col3, #T_6d05d_row13_col4, #T_6d05d_row14_col0, #T_6d05d_row14_col1, #T_6d05d_row14_col2, #T_6d05d_row14_col3, #T_6d05d_row14_col4, #T_6d05d_row15_col0, #T_6d05d_row15_col1, #T_6d05d_row15_col2, #T_6d05d_row15_col3, #T_6d05d_row15_col4, #T_6d05d_row16_col0, #T_6d05d_row16_col1, #T_6d05d_row16_col2, #T_6d05d_row16_col3, #T_6d05d_row16_col4, #T_6d05d_row17_col0, #T_6d05d_row17_col1, #T_6d05d_row17_col2, #T_6d05d_row17_col3, #T_6d05d_row17_col4, #T_6d05d_row18_col0, #T_6d05d_row18_col1, #T_6d05d_row18_col2, #T_6d05d_row18_col3, #T_6d05d_row18_col4, #T_6d05d_row19_col0, #T_6d05d_row19_col1, #T_6d05d_row19_col2, #T_6d05d_row19_col3, #T_6d05d_row19_col4, #T_6d05d_row20_col0, #T_6d05d_row20_col1, #T_6d05d_row20_col2, #T_6d05d_row20_col3, #T_6d05d_row20_col4, #T_6d05d_row21_col0, #T_6d05d_row21_col1, #T_6d05d_row21_col2, #T_6d05d_row21_col3, #T_6d05d_row21_col4, #T_6d05d_row22_col0, #T_6d05d_row22_col1, #T_6d05d_row22_col2, #T_6d05d_row22_col3, #T_6d05d_row22_col4, #T_6d05d_row23_col0, #T_6d05d_row23_col1, #T_6d05d_row23_col2, #T_6d05d_row23_col3, #T_6d05d_row23_col4, #T_6d05d_row24_col0, #T_6d05d_row24_col1, #T_6d05d_row24_col2, #T_6d05d_row24_col3, #T_6d05d_row24_col4, #T_6d05d_row25_col0, #T_6d05d_row25_col1, #T_6d05d_row25_col2, #T_6d05d_row25_col3, #T_6d05d_row25_col4, #T_6d05d_row26_col0, #T_6d05d_row26_col1, #T_6d05d_row26_col2, #T_6d05d_row26_col3, #T_6d05d_row26_col4 {
#   font-size: 9pt;
# }
# </style>
# <table id="T_6d05d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d05d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6d05d_level0_col1" class="col_heading level0 col1" >Balanced Accuracy</th>
#       <th id="T_6d05d_level0_col2" class="col_heading level0 col2" >ROC AUC</th>
#       <th id="T_6d05d_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_6d05d_level0_col4" class="col_heading level0 col4" >Time Taken</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d05d_level0_row0" class="row_heading level0 row0" >PassiveAggressiveClassifier</th>
#       <td id="T_6d05d_row0_col0" class="data row0 col0" >0.742690</td>
#       <td id="T_6d05d_row0_col1" class="data row0 col1" >0.863354</td>
#       <td id="T_6d05d_row0_col2" class="data row0 col2" >0.863354</td>
#       <td id="T_6d05d_row0_col3" class="data row0 col3" >0.810778</td>
#       <td id="T_6d05d_row0_col4" class="data row0 col4" >0.021298</td>
#     </tr>
#     <tr>
#       <th id="T_6d05d_level0_row1" class="row_heading level0 row1" >LinearDiscriminantAnalysis</th>
#       <td id="T_6d05d_row1_col0" class="data row1 col0" >0.883041</td>
#       <td id="T_6d05d_row1_col1" class="data row1 col1" >0.844099</td>
#       <td id="T_6d05d_row1_col2" class="data row1 col2" >0.844099</td>
#       <td id="T_6d05d_row1_col3" class="data row1 col3" >0.905974</td>
#       <td id="T_6d05d_row1_col4" class="data row1 col4" >0.052627</td>
#     </tr>
#     <tr>
#       <th id="T_6d05d_level0_row2" class="row_heading level0 row2" >RidgeClassifierCV</th>
#       <td id="T_6d05d_row2_col0" class="data row2 col0" >0.877193</td>
#       <td id="T_6d05d_row2_col1" class="data row2 col1" >0.840994</td>
#       <td id="T_6d05d_row2_col2" class="data row2 col2" >0.840994</td>
#       <td id="T_6d05d_row2_col3" class="data row2 col3" >0.901983</td>
#       <td id="T_6d05d_row2_col4" class="data row2 col4" >0.029590</td>
#     </tr>
#     <tr>
#       <th id="T_6d05d_level0_row3" class="row_heading level0 row3" >RidgeClassifier</th>
#       <td id="T_6d05d_row3_col0" class="data row3 col0" >0.877193</td>
#       <td id="T_6d05d_row3_col1" class="data row3 col1" >0.840994</td>
#       <td id="T_6d05d_row3_col2" class="data row3 col2" >0.840994</td>
#       <td id="T_6d05d_row3_col3" class="data row3 col3" >0.901983</td>
#       <td id="T_6d05d_row3_col4" class="data row3 col4" >0.015493</td>
#     </tr>
#     <tr>
#       <th id="T_6d05d_level0_row4" class="row_heading level0 row4" >SGDClassifier</th>
#       <td id="T_6d05d_row4_col0" class="data row4 col0" >0.789474</td>
#       <td id="T_6d05d_row4_col1" class="data row4 col1" >0.794410</td>
#       <td id="T_6d05d_row4_col2" class="data row4 col2" >0.794410</td>
#       <td id="T_6d05d_row4_col3" class="data row4 col3" >0.842636</td>
#       <td id="T_6d05d_row4_col4" class="data row4 col4" >0.044540</td>
#     </tr>
#     <tr>
#       <th id="T_6d05d_level0_row5" class="row_heading level0 row5" >LGBMClassifier</th>
#       <td id="T_6d05d_row5_col0" class="data row5 col0" >0.877193</td>
#       <td id="T_6d05d_row5_col1" class="data row5 col1" >0.794099</td>
#       <td id="T_6d05d_row5_col2" class="data row5 col2" >0.794099</td>
#       <td id="T_6d05d_row5_col3" class="data row5 col3" >0.900509</td>
#       <td id="T_6d05d_row5_col4" class="data row5 col4" >0.151831</td>
#     </tr>
#     <tr>
#       <th id="T_6d05d_level0_row6" class="row_heading level0 row6" >XGBClassifier</th>
#       <td id="T_6d05d_row6_col0" class="data row6 col0" >0.877193</td>
#       <td id="T_6d05d_row6_col1" class="data row6 col1" >0.794099</td>
#       <td id="T_6d05d_row6_col2" class="data row6 col2" >0.794099</td>
#       <td id="T_6d05d_row6_col3" class="data row6 col3" >0.900509</td>
#       <td id="T_6d05d_row6_col4" class="data row6 col4" >0.332430</td>
#     </tr>
#     <tr>
#       <th id="T_6d05d_level0_row7" class="row_heading level0 row7" >LogisticRegression</th>
#       <td id="T_6d05d_row7_col0" class="data row7 col0" >0.812865</td>
#       <td id="T_6d05d_row7_col1" class="data row7 col1" >0.759938</td>
#       <td id="T_6d05d_row7_col2" class="data row7 col2" >0.759938</td>
#       <td id="T_6d05d_row7_col3" class="data row7 col3" >0.857533</td>
#       <td id="T_6d05d_row7_col4" class="data row7 col4" >0.042060</td>
#     </tr>
#     <tr>
#       <th id="T_6d05d_level0_row8" class="row_heading level0 row8" >KNeighborsClassifier</th>
#       <td id="T_6d05d_row8_col0" class="data row8 col0" >0.707602</td>
#       <td id="T_6d05d_row8_col1" class="data row8 col1" >0.750932</td>
#       <td id="T_6d05d_row8_col2" class="data row8 col2" >0.750932</td>
#       <td id="T_6d05d_row8_col3" class="data row8 col3" >0.785132</td>
#       <td id="T_6d05d_row8_col4" class="data row8 col4" >0.016056</td>
#     </tr>
#     <tr>
#       <th id="T_6d05d_level0_row9" class="row_heading level0 row9" >LinearSVC</th>
#       <td id="T_6d05d_row9_col0" class="data row9 col0" >0.795

# %% [markdown]
# Explanation:
#
# 1) This code uses the following libraries:
#
# pandas: a library for data manipulation and analysis
# sklearn (Scikit-learn): a library for machine learning in Python
# IPython.display: a library for creating display objects for the Jupyter notebook
# lazypredict: a library for making machine learning easier and faster
# imblearn: a library for handling imbalanced datasets in machine learning.
#
#
# 2) The "group" variable:
#
# In this code represents the "patient_id" column in the dataset and is used as a grouping variable in the LeaveOneGroupOut cross-validation method.
#
#
# 3) LeaveOneGroupOut (LOGO)
#
# Is a cross-validation method used in machine learning to evaluate the performance of a model. The idea behind LOGO is to perform leave-one-out cross-validation (LOOCV) on group labels, instead of data samples. In this method, the data is divided into groups, and in each iteration, one entire group is left out for testing, and the rest of the groups are used for training. This way, the model is trained on data from all but one group, and then evaluated on the left-out group.The method "logo.split" is used to perform the cross-validation by splitting the data into training and test sets.
#
# More practical:
#
# The code is using the Leave-One-Group-Out cross-validation strategy, where each patient is considered a group. For each iteration of the loop, one patient is selected for testing and the remaining patients are used for training the model. In your example, if patient 61 is selected for testing, the model is trained on the data from patients 63, 71, 77, 82, 89, 93, 583, 657, 717, 723, 953, 965, 1002, 1021, 1041, 1043, and 1630. This is repeated for all patients, so each patient is used once for testing and all other patients are used for training.
#
#
# 4) SMOTE (Synthetic Minority Over-sampling Technique)
#
# Is a popular oversampling method used to handle imbalanced datasets in machine learning. Imbalanced datasets occur when the number of samples belonging to one class is much higher than the number of samples belonging to the other class. This can result in a biased model that performs poorly on the minority class. SMOTE works by creating synthetic samples of the minority class instead of simply duplicating the existing samples. The algorithm does this by selecting a sample from the minority class and finding its k nearest neighbors. Then, it generates synthetic samples by interpolating between the selected sample and its neighbors. This process helps to create more diverse and representative samples for the minority class and thus helps to balance the class distribution.
# In this code, the SMOTE method is used to oversample the minority class in the training data. The SMOTE object "sm" is created using the "SMOTE" class from the imblearn library, with the sampling_strategy set to 'auto'. The "fit_resample" method is then used to apply the SMOTE method to the training data. The result is a balanced training set with an equal number of samples from each class.
#
#
# 5) An explanation of each evaluation metric:
#
# Accuracy: The proportion of correctly classified samples out of the total number of samples. It is a simple and commonly used metric to evaluate the performance of a classifier. However, it may not be suitable when the classes are imbalanced.
#
# Balanced Accuracy: Similar to accuracy, but takes into account the imbalance of the classes. It is the average of sensitivity (true positive rate) and specificity (true negative rate).
#
# ROC AUC: Receiver Operating Characteristic (ROC) curve is a plot of the true positive rate (sensitivity) versus the false positive rate (1 - specificity) for different classification thresholds. Area Under the Curve (AUC) of the ROC curve is a metric that measures the performance of the classifier across all possible thresholds. It is a useful metric when the classes are imbalanced, and it gives an idea of how well the classifier can discriminate between positive and negative samples.
#
# F1 Score: The harmonic mean of precision and recall. It is a metric that balances the importance of precision (the proportion of true positives out of all predicted positives) and recall (the proportion of true positives out of all actual positives). It is a good metric when the classes are imbalanced, and it gives a balanced view of the classifier's performance.
